# %%
from wp2_functions import drf_features_from_rsmi, drf_wl_features_from_rsmi, plot_wl_drf_iterations_from_rsmi, wl_feature_sets_per_iter_graph, drf_wl_features_per_iter_from_rsmi, plot_wl_drf_feature_growth_from_rsmi
import pandas as pd
from vis_utils import plot_drf_from_counters_rsmi
import plotly.io as pio
from synkit.IO import rsmi_to_graph
pio.renderers.default = "vscode"

# %% [markdown]
# TODOs:
#
# 1. Implement transformations Φ for Vertex-, Edge- and Shortest-Path Labels.
# 2. Implement the DRF transformation function.
# 3. Implement Weisfeiler-Lehman with applications of Φ such that hashed feature sets are
# returned at every iteration.
# 4. Pre-compute feature hash sets for all datasets

# %%
# one rsmi for testing

path = "schneider50k_clean.tsv"
data = pd.read_csv(path, sep="\t")
rsmi = data["clean_rxn"].iloc[20]
print(rsmi)
# Out:
# [NH2:1][CH2:2][c:3]1[cH:33][cH:32][cH:31][c:5]([CH2:6][N:7]([CH2:20][c:21]2[cH:22][cH:23][c:24]([C:27]([F:28])([F:29])[F:30])[cH:25][cH:26]2)[S:8](=[O:9])(=[O:10])[c:11]2[cH:16][c:15]([Cl:17])[cH:14][c:13]([Cl:18])[c:12]2[OH:19])[cH:4]1.[O:44]=[C:43]=[N:42][c:36]1[cH:37][cH:38][c:39]([F:41])[cH:40][c:35]1[F:34]>>[O:44]=[C:43]([NH:1][CH2:2][c:3]1[cH:33][cH:32][cH:31][c:5]([CH2:6][N:7]([CH2:20][c:21]2[cH:26][cH:25][c:24]([C:27]([F:30])([F:28])[F:29])[cH:23][cH:22]2)[S:8](=[O:10])(=[O:9])[c:11]2[cH:16][c:15]([Cl:17])[cH:14][c:13]([Cl:18])[c:12]2[OH:19])[cH:4]1)[NH:42][c:36]1[cH:37][cH:38][c:39]([F:41])[cH:40][c:35]1[F:34]

# %% [markdown]
# ## 1. + 2. Implement transformations Φ for Vertex-, Edge- and Shortest-Path Labels + Implement the DRF transformation function.

# %% [markdown]
# In WP2, reactions are represented using **Differential Reaction Fingerprints (DRF)**.
# For a reaction \( R = (E_R, P_R) \), feature representations are first computed
# separately for the reactant graph \( \Phi(E_R) \) and the product graph \( \Phi(P_R) \).
#
# The reaction representation is then defined as the **symmetric difference**
# between these two feature multisets:
# \[
# \Phi_{\text{reaction}}(R) = \Phi(E_R) \,\Delta\, \Phi(P_R)
# \]
#
# This operation removes features that appear in both reactants and products
# and keeps only those features that change during the reaction.
# In this implementation, features are treated as **multisets** (using feature counts),
# so the symmetric difference is computed as the absolute difference of feature frequencies.
#
# Depending on the chosen mode, DRF can be constructed from
# vertex labels, edge labels, or shortest-path features.
# This representation focuses explicitly on structural changes
# and is used as input for kernel-based similarity computations in later steps.

# %% [markdown]
# → DRF filters out everything that does not belong to the reaction.
# → Only the change itself remains.

# %% [markdown]
# ### Comparing DRF Feature Types
#
# This cell computes Differential Reaction Fingerprints (DRF) using different base
# feature mappings (vertex labels, edge labels, and shortest paths).
# The resulting feature counts illustrate how the choice of Φ affects the richness
# and granularity of the reaction representation.

# %%
drf_E = drf_features_from_rsmi(rsmi, mode="edge")
drf_V = drf_features_from_rsmi(rsmi, mode="vertex")
drf_SP = drf_features_from_rsmi(rsmi, mode="sp", include_edge_labels_in_sp=True)

print("DRF edge feature count:", sum(drf_E.values()))
print("DRF vertex feature count:", sum(drf_V.values()))
print("DRF shortest-path feature count:", sum(drf_SP.values()))

# Optional: ein paar Einträge ansehen
print("Sample DRF edge items:", list(drf_E.items())[:10])
# Out:
# DRF edge feature count: 3
# DRF vertex feature count: 0
# DRF shortest-path feature count: 399
# Sample DRF edge items: [('e79537351a6bc51d5c4fbea90fec0b26', 2), ('095751d849efbdb232d632cd4a7fc89e', 1)]

# %% [markdown]
# ### Visualizing DRF Features for Different Φ Mappings
#
# This cell visualizes the Differential Reaction Fingerprints derived from different
# base feature mappings (edge, vertex, and shortest-path features).
# Highlighted graph elements indicate structural differences between reactants and
# products that contribute to the DRF representation.

# %%
fig_e = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_E,
    mode="edge",
    hash_labels=True,              
    digest_size=16,                 
    show_edge_labels=True,
)
fig_e.show(renderer="vscode")

fig_v = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_V,
    mode="vertex",
    hash_labels=True,
    digest_size=16,
)
fig_v.show(renderer="vscode")

fig_sp = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_SP,
    mode="sp",
    include_edge_labels_in_sp=True, 
    hash_labels=True,
    digest_size=16,
)
fig_sp.show(renderer="vscode")

# %% [markdown]
# ## 3. Implement Weisfeiler-Lehman with applications of Φ such that hashed feature sets are returned at every iteration.

# %% [markdown]
# The Weisfeiler–Lehman (WL) algorithm iteratively refines node labels by incorporating
# the labels of neighboring nodes. Starting from initial node labels (e.g. atom types),
# each WL iteration constructs a new label for every node based on its current label
# and the multiset of its neighbors’ labels, followed by hashing.
#
# This process enriches node labels with increasingly larger local neighborhood
# information. After each iteration, feature maps Φ are applied to the relabeled graph
# and the resulting hashed feature sets are stored. These WL-enhanced features capture
# local substructures of the graph up to a given neighborhood depth and are later used
# for kernel-based similarity computations.
#
# → WL iteratively enriches node labels with neighborhood information, capturing increasingly complex local graph structures.
# → WL = wiederholtes Relabeling von Knoten anhand ihrer Nachbarschaft (und Hashing dieser neuen Labels).

# %% [markdown]
# ### WL-Enhanced DRF Feature Counts
#
# This cell computes Differential Reaction Fingerprints combined with Weisfeiler–Lehman
# (WL) relabeling for different base feature mappings (edge, vertex, and shortest paths).
# The printed counts summarize the total amount of structural change captured when
# neighborhood information up to WL depth h=3 is incorporated.

# %%
drf_wl_E = drf_wl_features_from_rsmi(rsmi, h=3, mode="edge")
drf_wl_V = drf_wl_features_from_rsmi(rsmi, h=3, mode="vertex")
drf_wl_SP = drf_wl_features_from_rsmi(rsmi, h=3, mode="sp", include_edge_labels_in_sp=True)
print(sum(drf_wl_E.values()), sum(drf_wl_V.values()), sum(drf_wl_SP.values()))
# Out:
# 40 28 2090

# %% [markdown]
# ### WL Feature Sets per Iteration
#
# This cell computes feature sets for a single graph after successive
# Weisfeiler–Lehman (WL) iterations.
# The printed values show how the number of extracted features grows with increasing
# WL depth, illustrating how neighborhood information is progressively incorporated.

# %%
ed, pr = rsmi_to_graph(rsmi)

sets_per_iter = wl_feature_sets_per_iter_graph(ed, h=3, mode="edge")  # Liste von Sets
print([len(s) for s in sets_per_iter])
# Out:
# [11, 23, 34, 38]

# %% [markdown]
# ### WL–DRF Features per Iteration and Visualization
#
# This cell computes WL-enhanced DRF features separately for each WL iteration and
# prints their total counts.
# The accompanying visualization highlights, for each iteration, which graph elements
# contribute to the DRF representation, illustrating how increasingly larger
# neighborhood information influences the detected reaction changes.
#
# Red graph elements indicate nodes or edges that contribute to the DRF representation, i.e. structural changes between reactants and products.
# (Rot markiert = das ist die Reaktion.
# Grau = chemisch irrelevant Hintergrund.)

# %%
per_iter, total = drf_wl_features_per_iter_from_rsmi(rsmi, h=3, mode="edge")
print([sum(c.values()) for c in per_iter], "sum:", sum(total.values()))


fig = plot_wl_drf_iterations_from_rsmi(rsmi, h=3, mode="edge", show_edge_labels=True)
fig.show()
# Out:
# [3, 7, 11, 19] sum: 40

# %% [markdown]
# ### WL–DRF Feature Growth Across Iterations
# This plot shows how the number and magnitude of DRF features evolve across WL iterations.
# It illustrates how successive WL relabeling steps introduce additional structural
# information until the representation saturates.

# %% [markdown]
# The WL-DRF feature growth shows that successive WL iterations introduce additional structural information. No saturation is observed up to h=3, indicating that deeper neighborhood information contributes meaningfully to the reaction representation.
# Das Diagramm zeigt, dass WL die DRF-Repräsentation schrittweise anreichert
# und bis Iteration 3 noch keine Sättigung erreicht ist.

# %%
fig = plot_wl_drf_feature_growth_from_rsmi(rsmi, h=3, mode="edge", show_cumulative=True)
fig.show()

# %% [markdown]
# ## Pre-computing Feature Hash Sets
#
# In this step, feature representations are pre-computed for all reactions in the dataset.
# For each reaction, hashed feature sets are generated using the previously defined
# DRF and WL–DRF transformations and stored for later use.
#
# This pre-computation avoids repeated and expensive feature extraction during kernel
# construction and enables efficient and reproducible experiments in subsequent work packages.

# %% [markdown]
# ### Pre-computing WL–DRF Feature Representations
#
# In this step, WL–DRF feature representations are pre-computed for all reactions in the
# selected datasets and stored on disk.
# This avoids repeated and expensive feature extraction and enables efficient kernel
# construction in subsequent work packages.

# %%
from wp2_precompute_features import precompute_all_subsets_in_dir

precompute_all_subsets_in_dir(
    subsets_dir="subsets_small",
    out_dir="precomputed",
    pattern="subset*.tsv",
    drf_mode="edge",
    wl_h=3,
    wl_mode="edge",
)
# Out:
# [+] Precomputing subset_001.tsv -> subset_001.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_002.tsv -> subset_002.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_003.tsv -> subset_003.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_004.tsv -> subset_004.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_005.tsv -> subset_005.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_006.tsv -> subset_006.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_007.tsv -> subset_007.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_008.tsv -> subset_008.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_009.tsv -> subset_009.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_010.tsv -> subset_010.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_011.tsv -> subset_011.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_012.tsv -> subset_012.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_013.tsv -> subset_013.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_014.tsv -> subset_014.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_015.tsv -> subset_015.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_016.tsv -> subset_016.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_017.tsv -> subset_017.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_018.tsv -> subset_018.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_019.tsv -> subset_019.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_020.tsv -> subset_020.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_021.tsv -> subset_021.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_022.tsv -> subset_022.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_023.tsv -> subset_023.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_024.tsv -> subset_024.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_025.tsv -> subset_025.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_026.tsv -> subset_026.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_027.tsv -> subset_027.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_028.tsv -> subset_028.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_029.tsv -> subset_029.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_030.tsv -> subset_030.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_031.tsv -> subset_031.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_032.tsv -> subset_032.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_033.tsv -> subset_033.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_034.tsv -> subset_034.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_035.tsv -> subset_035.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_036.tsv -> subset_036.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_037.tsv -> subset_037.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_038.tsv -> subset_038.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_039.tsv -> subset_039.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_040.tsv -> subset_040.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_041.tsv -> subset_041.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_042.tsv -> subset_042.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_043.tsv -> subset_043.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_044.tsv -> subset_044.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_045.tsv -> subset_045.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_046.tsv -> subset_046.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_047.tsv -> subset_047.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_048.tsv -> subset_048.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_049.tsv -> subset_049.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_050.tsv -> subset_050.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_051.tsv -> subset_051.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_052.tsv -> subset_052.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_053.tsv -> subset_053.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_054.tsv -> subset_054.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_055.tsv -> subset_055.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_056.tsv -> subset_056.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_057.tsv -> subset_057.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_058.tsv -> subset_058.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_059.tsv -> subset_059.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_060.tsv -> subset_060.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_061.tsv -> subset_061.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_062.tsv -> subset_062.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_063.tsv -> subset_063.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_064.tsv -> subset_064.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_065.tsv -> subset_065.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_066.tsv -> subset_066.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_067.tsv -> subset_067.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_068.tsv -> subset_068.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_069.tsv -> subset_069.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_070.tsv -> subset_070.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_071.tsv -> subset_071.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_072.tsv -> subset_072.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_073.tsv -> subset_073.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_074.tsv -> subset_074.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_075.tsv -> subset_075.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_076.tsv -> subset_076.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_077.tsv -> subset_077.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_078.tsv -> subset_078.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_079.tsv -> subset_079.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_080.tsv -> subset_080.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_081.tsv -> subset_081.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_082.tsv -> subset_082.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_083.tsv -> subset_083.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_084.tsv -> subset_084.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_085.tsv -> subset_085.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_086.tsv -> subset_086.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_087.tsv -> subset_087.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_088.tsv -> subset_088.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_089.tsv -> subset_089.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_090.tsv -> subset_090.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_091.tsv -> subset_091.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_092.tsv -> subset_092.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_093.tsv -> subset_093.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_094.tsv -> subset_094.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_095.tsv -> subset_095.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_096.tsv -> subset_096.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_097.tsv -> subset_097.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_098.tsv -> subset_098.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_099.tsv -> subset_099.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_100.tsv -> subset_100.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_101.tsv -> subset_101.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_102.tsv -> subset_102.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_103.tsv -> subset_103.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_104.tsv -> subset_104.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_105.tsv -> subset_105.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_106.tsv -> subset_106.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_107.tsv -> subset_107.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_108.tsv -> subset_108.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_109.tsv -> subset_109.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_110.tsv -> subset_110.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_111.tsv -> subset_111.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_112.tsv -> subset_112.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_113.tsv -> subset_113.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_114.tsv -> subset_114.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_115.tsv -> subset_115.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_116.tsv -> subset_116.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_117.tsv -> subset_117.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_118.tsv -> subset_118.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_119.tsv -> subset_119.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_120.tsv -> subset_120.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_121.tsv -> subset_121.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_122.tsv -> subset_122.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_123.tsv -> subset_123.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_124.tsv -> subset_124.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_125.tsv -> subset_125.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_126.tsv -> subset_126.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_127.tsv -> subset_127.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_128.tsv -> subset_128.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_129.tsv -> subset_129.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_130.tsv -> subset_130.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_131.tsv -> subset_131.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_132.tsv -> subset_132.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_133.tsv -> subset_133.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_134.tsv -> subset_134.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_135.tsv -> subset_135.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_136.tsv -> subset_136.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_137.tsv -> subset_137.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_138.tsv -> subset_138.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_139.tsv -> subset_139.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_140.tsv -> subset_140.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_141.tsv -> subset_141.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_142.tsv -> subset_142.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_143.tsv -> subset_143.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_144.tsv -> subset_144.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_145.tsv -> subset_145.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_146.tsv -> subset_146.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_147.tsv -> subset_147.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_148.tsv -> subset_148.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_149.tsv -> subset_149.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_150.tsv -> subset_150.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_151.tsv -> subset_151.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_152.tsv -> subset_152.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_153.tsv -> subset_153.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_154.tsv -> subset_154.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_155.tsv -> subset_155.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_156.tsv -> subset_156.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_157.tsv -> subset_157.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_158.tsv -> subset_158.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_159.tsv -> subset_159.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_160.tsv -> subset_160.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_161.tsv -> subset_161.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_162.tsv -> subset_162.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_163.tsv -> subset_163.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_164.tsv -> subset_164.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_165.tsv -> subset_165.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_166.tsv -> subset_166.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_167.tsv -> subset_167.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_168.tsv -> subset_168.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_169.tsv -> subset_169.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_170.tsv -> subset_170.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_171.tsv -> subset_171.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_172.tsv -> subset_172.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_173.tsv -> subset_173.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_174.tsv -> subset_174.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_175.tsv -> subset_175.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_176.tsv -> subset_176.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_177.tsv -> subset_177.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_178.tsv -> subset_178.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_179.tsv -> subset_179.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_180.tsv -> subset_180.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_181.tsv -> subset_181.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_182.tsv -> subset_182.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_183.tsv -> subset_183.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_184.tsv -> subset_184.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_185.tsv -> subset_185.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_186.tsv -> subset_186.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_187.tsv -> subset_187.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_188.tsv -> subset_188.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_189.tsv -> subset_189.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_190.tsv -> subset_190.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_191.tsv -> subset_191.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_192.tsv -> subset_192.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_193.tsv -> subset_193.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_194.tsv -> subset_194.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_195.tsv -> subset_195.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_196.tsv -> subset_196.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_197.tsv -> subset_197.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_198.tsv -> subset_198.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_199.tsv -> subset_199.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_200.tsv -> subset_200.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_201.tsv -> subset_201.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_202.tsv -> subset_202.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_203.tsv -> subset_203.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_204.tsv -> subset_204.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_205.tsv -> subset_205.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_206.tsv -> subset_206.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_207.tsv -> subset_207.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_208.tsv -> subset_208.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_209.tsv -> subset_209.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_210.tsv -> subset_210.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_211.tsv -> subset_211.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_212.tsv -> subset_212.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_213.tsv -> subset_213.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_214.tsv -> subset_214.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_215.tsv -> subset_215.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_216.tsv -> subset_216.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_217.tsv -> subset_217.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_218.tsv -> subset_218.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_219.tsv -> subset_219.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_220.tsv -> subset_220.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_221.tsv -> subset_221.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_222.tsv -> subset_222.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_223.tsv -> subset_223.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_224.tsv -> subset_224.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_225.tsv -> subset_225.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_226.tsv -> subset_226.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_227.tsv -> subset_227.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_228.tsv -> subset_228.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_229.tsv -> subset_229.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_230.tsv -> subset_230.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_231.tsv -> subset_231.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_232.tsv -> subset_232.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_233.tsv -> subset_233.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_234.tsv -> subset_234.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_235.tsv -> subset_235.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_236.tsv -> subset_236.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_237.tsv -> subset_237.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_238.tsv -> subset_238.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_239.tsv -> subset_239.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_240.tsv -> subset_240.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_241.tsv -> subset_241.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_242.tsv -> subset_242.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_243.tsv -> subset_243.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_244.tsv -> subset_244.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_245.tsv -> subset_245.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_246.tsv -> subset_246.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_247.tsv -> subset_247.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_248.tsv -> subset_248.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_249.tsv -> subset_249.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_250.tsv -> subset_250.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_251.tsv -> subset_251.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_252.tsv -> subset_252.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_253.tsv -> subset_253.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_254.tsv -> subset_254.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_255.tsv -> subset_255.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_256.tsv -> subset_256.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_257.tsv -> subset_257.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_258.tsv -> subset_258.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_259.tsv -> subset_259.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_260.tsv -> subset_260.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_261.tsv -> subset_261.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_262.tsv -> subset_262.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_263.tsv -> subset_263.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_264.tsv -> subset_264.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_265.tsv -> subset_265.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_266.tsv -> subset_266.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_267.tsv -> subset_267.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_268.tsv -> subset_268.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_269.tsv -> subset_269.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_270.tsv -> subset_270.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_271.tsv -> subset_271.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_272.tsv -> subset_272.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_273.tsv -> subset_273.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_274.tsv -> subset_274.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_275.tsv -> subset_275.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_276.tsv -> subset_276.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_277.tsv -> subset_277.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_278.tsv -> subset_278.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_279.tsv -> subset_279.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_280.tsv -> subset_280.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_281.tsv -> subset_281.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_282.tsv -> subset_282.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_283.tsv -> subset_283.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_284.tsv -> subset_284.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_285.tsv -> subset_285.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_286.tsv -> subset_286.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_287.tsv -> subset_287.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_288.tsv -> subset_288.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_289.tsv -> subset_289.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_290.tsv -> subset_290.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_291.tsv -> subset_291.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_292.tsv -> subset_292.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_293.tsv -> subset_293.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_294.tsv -> subset_294.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_295.tsv -> subset_295.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_296.tsv -> subset_296.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_297.tsv -> subset_297.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_298.tsv -> subset_298.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_299.tsv -> subset_299.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_300.tsv -> subset_300.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_301.tsv -> subset_301.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_302.tsv -> subset_302.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_303.tsv -> subset_303.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_304.tsv -> subset_304.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_305.tsv -> subset_305.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_306.tsv -> subset_306.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_307.tsv -> subset_307.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_308.tsv -> subset_308.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_309.tsv -> subset_309.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_310.tsv -> subset_310.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_311.tsv -> subset_311.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_312.tsv -> subset_312.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_313.tsv -> subset_313.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_314.tsv -> subset_314.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_315.tsv -> subset_315.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_316.tsv -> subset_316.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_317.tsv -> subset_317.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_318.tsv -> subset_318.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_319.tsv -> subset_319.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_320.tsv -> subset_320.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_321.tsv -> subset_321.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_322.tsv -> subset_322.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_323.tsv -> subset_323.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_324.tsv -> subset_324.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_325.tsv -> subset_325.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_326.tsv -> subset_326.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_327.tsv -> subset_327.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_328.tsv -> subset_328.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_329.tsv -> subset_329.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_330.tsv -> subset_330.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_331.tsv -> subset_331.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_332.tsv -> subset_332.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_333.tsv -> subset_333.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_334.tsv -> subset_334.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_335.tsv -> subset_335.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_336.tsv -> subset_336.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_337.tsv -> subset_337.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_338.tsv -> subset_338.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_339.tsv -> subset_339.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_340.tsv -> subset_340.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_341.tsv -> subset_341.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_342.tsv -> subset_342.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_343.tsv -> subset_343.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_344.tsv -> subset_344.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_345.tsv -> subset_345.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_346.tsv -> subset_346.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_347.tsv -> subset_347.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_348.tsv -> subset_348.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_349.tsv -> subset_349.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_350.tsv -> subset_350.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_351.tsv -> subset_351.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_352.tsv -> subset_352.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_353.tsv -> subset_353.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_354.tsv -> subset_354.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_355.tsv -> subset_355.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_356.tsv -> subset_356.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_357.tsv -> subset_357.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_358.tsv -> subset_358.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_359.tsv -> subset_359.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_360.tsv -> subset_360.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_361.tsv -> subset_361.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_362.tsv -> subset_362.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_363.tsv -> subset_363.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_364.tsv -> subset_364.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_365.tsv -> subset_365.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_366.tsv -> subset_366.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_367.tsv -> subset_367.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_368.tsv -> subset_368.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_369.tsv -> subset_369.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_370.tsv -> subset_370.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_371.tsv -> subset_371.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_372.tsv -> subset_372.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_373.tsv -> subset_373.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_374.tsv -> subset_374.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_375.tsv -> subset_375.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_376.tsv -> subset_376.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_377.tsv -> subset_377.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_378.tsv -> subset_378.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_379.tsv -> subset_379.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_380.tsv -> subset_380.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_381.tsv -> subset_381.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_382.tsv -> subset_382.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_383.tsv -> subset_383.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_384.tsv -> subset_384.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_385.tsv -> subset_385.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_386.tsv -> subset_386.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_387.tsv -> subset_387.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_388.tsv -> subset_388.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_389.tsv -> subset_389.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_390.tsv -> subset_390.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_391.tsv -> subset_391.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_392.tsv -> subset_392.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_393.tsv -> subset_393.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_394.tsv -> subset_394.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_395.tsv -> subset_395.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_396.tsv -> subset_396.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_397.tsv -> subset_397.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_398.tsv -> subset_398.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_399.tsv -> subset_399.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_400.tsv -> subset_400.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_401.tsv -> subset_401.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_402.tsv -> subset_402.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_403.tsv -> subset_403.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_404.tsv -> subset_404.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_405.tsv -> subset_405.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_406.tsv -> subset_406.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_407.tsv -> subset_407.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_408.tsv -> subset_408.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_409.tsv -> subset_409.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_410.tsv -> subset_410.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_411.tsv -> subset_411.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_412.tsv -> subset_412.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_413.tsv -> subset_413.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_414.tsv -> subset_414.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_415.tsv -> subset_415.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_416.tsv -> subset_416.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_417.tsv -> subset_417.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_418.tsv -> subset_418.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_419.tsv -> subset_419.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_420.tsv -> subset_420.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_421.tsv -> subset_421.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_422.tsv -> subset_422.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_423.tsv -> subset_423.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_424.tsv -> subset_424.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_425.tsv -> subset_425.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_426.tsv -> subset_426.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_427.tsv -> subset_427.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_428.tsv -> subset_428.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_429.tsv -> subset_429.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_430.tsv -> subset_430.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_431.tsv -> subset_431.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_432.tsv -> subset_432.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_433.tsv -> subset_433.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_434.tsv -> subset_434.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_435.tsv -> subset_435.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_436.tsv -> subset_436.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_437.tsv -> subset_437.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_438.tsv -> subset_438.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_439.tsv -> subset_439.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_440.tsv -> subset_440.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_441.tsv -> subset_441.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_442.tsv -> subset_442.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_443.tsv -> subset_443.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_444.tsv -> subset_444.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_445.tsv -> subset_445.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_446.tsv -> subset_446.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_447.tsv -> subset_447.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_448.tsv -> subset_448.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_449.tsv -> subset_449.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_450.tsv -> subset_450.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_451.tsv -> subset_451.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_452.tsv -> subset_452.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_453.tsv -> subset_453.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_454.tsv -> subset_454.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_455.tsv -> subset_455.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_456.tsv -> subset_456.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_457.tsv -> subset_457.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_458.tsv -> subset_458.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_459.tsv -> subset_459.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_460.tsv -> subset_460.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_461.tsv -> subset_461.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_462.tsv -> subset_462.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_463.tsv -> subset_463.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_464.tsv -> subset_464.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_465.tsv -> subset_465.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_466.tsv -> subset_466.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_467.tsv -> subset_467.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_468.tsv -> subset_468.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_469.tsv -> subset_469.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_470.tsv -> subset_470.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_471.tsv -> subset_471.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_472.tsv -> subset_472.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_473.tsv -> subset_473.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_474.tsv -> subset_474.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_475.tsv -> subset_475.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_476.tsv -> subset_476.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_477.tsv -> subset_477.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_478.tsv -> subset_478.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_479.tsv -> subset_479.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_480.tsv -> subset_480.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_481.tsv -> subset_481.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_482.tsv -> subset_482.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_483.tsv -> subset_483.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_484.tsv -> subset_484.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_485.tsv -> subset_485.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_486.tsv -> subset_486.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_487.tsv -> subset_487.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_488.tsv -> subset_488.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_489.tsv -> subset_489.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_490.tsv -> subset_490.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_491.tsv -> subset_491.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_492.tsv -> subset_492.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_493.tsv -> subset_493.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_494.tsv -> subset_494.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_495.tsv -> subset_495.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_496.tsv -> subset_496.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_497.tsv -> subset_497.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_498.tsv -> subset_498.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_499.tsv -> subset_499.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_500.tsv -> subset_500.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_501.tsv -> subset_501.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_502.tsv -> subset_502.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_503.tsv -> subset_503.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_504.tsv -> subset_504.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_505.tsv -> subset_505.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_506.tsv -> subset_506.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_507.tsv -> subset_507.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_508.tsv -> subset_508.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_509.tsv -> subset_509.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_510.tsv -> subset_510.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_511.tsv -> subset_511.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_512.tsv -> subset_512.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_513.tsv -> subset_513.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_514.tsv -> subset_514.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_515.tsv -> subset_515.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_516.tsv -> subset_516.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_517.tsv -> subset_517.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_518.tsv -> subset_518.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_519.tsv -> subset_519.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_520.tsv -> subset_520.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_521.tsv -> subset_521.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_522.tsv -> subset_522.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_523.tsv -> subset_523.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_524.tsv -> subset_524.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_525.tsv -> subset_525.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_526.tsv -> subset_526.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_527.tsv -> subset_527.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_528.tsv -> subset_528.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_529.tsv -> subset_529.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_530.tsv -> subset_530.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_531.tsv -> subset_531.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_532.tsv -> subset_532.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_533.tsv -> subset_533.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_534.tsv -> subset_534.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_535.tsv -> subset_535.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_536.tsv -> subset_536.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_537.tsv -> subset_537.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_538.tsv -> subset_538.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_539.tsv -> subset_539.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_540.tsv -> subset_540.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_541.tsv -> subset_541.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_542.tsv -> subset_542.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_543.tsv -> subset_543.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_544.tsv -> subset_544.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_545.tsv -> subset_545.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_546.tsv -> subset_546.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_547.tsv -> subset_547.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_548.tsv -> subset_548.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_549.tsv -> subset_549.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_550.tsv -> subset_550.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_551.tsv -> subset_551.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_552.tsv -> subset_552.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_553.tsv -> subset_553.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_554.tsv -> subset_554.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_555.tsv -> subset_555.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_556.tsv -> subset_556.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_557.tsv -> subset_557.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_558.tsv -> subset_558.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_559.tsv -> subset_559.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_560.tsv -> subset_560.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_561.tsv -> subset_561.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_562.tsv -> subset_562.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_563.tsv -> subset_563.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_564.tsv -> subset_564.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_565.tsv -> subset_565.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_566.tsv -> subset_566.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_567.tsv -> subset_567.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_568.tsv -> subset_568.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_569.tsv -> subset_569.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_570.tsv -> subset_570.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_571.tsv -> subset_571.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_572.tsv -> subset_572.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_573.tsv -> subset_573.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_574.tsv -> subset_574.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_575.tsv -> subset_575.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_576.tsv -> subset_576.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_577.tsv -> subset_577.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_578.tsv -> subset_578.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_579.tsv -> subset_579.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_580.tsv -> subset_580.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_581.tsv -> subset_581.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_582.tsv -> subset_582.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_583.tsv -> subset_583.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_584.tsv -> subset_584.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_585.tsv -> subset_585.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_586.tsv -> subset_586.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_587.tsv -> subset_587.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_588.tsv -> subset_588.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_589.tsv -> subset_589.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_590.tsv -> subset_590.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_591.tsv -> subset_591.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_592.tsv -> subset_592.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_593.tsv -> subset_593.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_594.tsv -> subset_594.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_595.tsv -> subset_595.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_596.tsv -> subset_596.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_597.tsv -> subset_597.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_598.tsv -> subset_598.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_599.tsv -> subset_599.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_600.tsv -> subset_600.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_601.tsv -> subset_601.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_602.tsv -> subset_602.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_603.tsv -> subset_603.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_604.tsv -> subset_604.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_605.tsv -> subset_605.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_606.tsv -> subset_606.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_607.tsv -> subset_607.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_608.tsv -> subset_608.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_609.tsv -> subset_609.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_610.tsv -> subset_610.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_611.tsv -> subset_611.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_612.tsv -> subset_612.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_613.tsv -> subset_613.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_614.tsv -> subset_614.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_615.tsv -> subset_615.reaction_features_drf_wl_h3.pkl
# ...
# [+] Precomputing subset_630.tsv -> subset_630.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_631.tsv -> subset_631.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_632.tsv -> subset_632.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_633.tsv -> subset_633.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_634.tsv -> subset_634.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_635.tsv -> subset_635.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_636.tsv -> subset_636.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_637.tsv -> subset_637.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_638.tsv -> subset_638.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_639.tsv -> subset_639.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_640.tsv -> subset_640.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_641.tsv -> subset_641.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_642.tsv -> subset_642.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_643.tsv -> subset_643.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_644.tsv -> subset_644.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_645.tsv -> subset_645.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_646.tsv -> subset_646.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_647.tsv -> subset_647.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_648.tsv -> subset_648.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_649.tsv -> subset_649.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_650.tsv -> subset_650.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_651.tsv -> subset_651.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_652.tsv -> subset_652.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_653.tsv -> subset_653.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_654.tsv -> subset_654.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_655.tsv -> subset_655.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_656.tsv -> subset_656.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_657.tsv -> subset_657.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_658.tsv -> subset_658.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_659.tsv -> subset_659.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_660.tsv -> subset_660.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_661.tsv -> subset_661.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_662.tsv -> subset_662.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_663.tsv -> subset_663.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_664.tsv -> subset_664.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_665.tsv -> subset_665.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_666.tsv -> subset_666.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_667.tsv -> subset_667.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_668.tsv -> subset_668.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_669.tsv -> subset_669.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_670.tsv -> subset_670.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_671.tsv -> subset_671.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_672.tsv -> subset_672.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_673.tsv -> subset_673.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_674.tsv -> subset_674.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_675.tsv -> subset_675.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_676.tsv -> subset_676.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_677.tsv -> subset_677.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_678.tsv -> subset_678.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_679.tsv -> subset_679.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_680.tsv -> subset_680.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_681.tsv -> subset_681.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_682.tsv -> subset_682.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_683.tsv -> subset_683.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_684.tsv -> subset_684.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_685.tsv -> subset_685.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_686.tsv -> subset_686.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_687.tsv -> subset_687.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_688.tsv -> subset_688.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_689.tsv -> subset_689.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_690.tsv -> subset_690.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_691.tsv -> subset_691.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_692.tsv -> subset_692.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_693.tsv -> subset_693.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_694.tsv -> subset_694.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_695.tsv -> subset_695.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_696.tsv -> subset_696.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_697.tsv -> subset_697.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_698.tsv -> subset_698.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_699.tsv -> subset_699.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_700.tsv -> subset_700.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_701.tsv -> subset_701.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_702.tsv -> subset_702.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_703.tsv -> subset_703.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_704.tsv -> subset_704.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_705.tsv -> subset_705.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_706.tsv -> subset_706.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_707.tsv -> subset_707.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_708.tsv -> subset_708.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_709.tsv -> subset_709.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_710.tsv -> subset_710.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_711.tsv -> subset_711.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_712.tsv -> subset_712.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_713.tsv -> subset_713.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_714.tsv -> subset_714.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_715.tsv -> subset_715.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_716.tsv -> subset_716.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_717.tsv -> subset_717.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_718.tsv -> subset_718.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_719.tsv -> subset_719.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_720.tsv -> subset_720.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_721.tsv -> subset_721.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_722.tsv -> subset_722.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_723.tsv -> subset_723.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_724.tsv -> subset_724.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_725.tsv -> subset_725.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_726.tsv -> subset_726.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_727.tsv -> subset_727.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_728.tsv -> subset_728.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_729.tsv -> subset_729.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_730.tsv -> subset_730.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_731.tsv -> subset_731.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_732.tsv -> subset_732.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_733.tsv -> subset_733.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_734.tsv -> subset_734.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_735.tsv -> subset_735.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_736.tsv -> subset_736.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_737.tsv -> subset_737.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_738.tsv -> subset_738.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_739.tsv -> subset_739.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_740.tsv -> subset_740.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_741.tsv -> subset_741.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_742.tsv -> subset_742.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_743.tsv -> subset_743.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_744.tsv -> subset_744.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_745.tsv -> subset_745.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_746.tsv -> subset_746.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_747.tsv -> subset_747.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_748.tsv -> subset_748.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_749.tsv -> subset_749.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_750.tsv -> subset_750.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_751.tsv -> subset_751.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_752.tsv -> subset_752.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_753.tsv -> subset_753.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_754.tsv -> subset_754.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_755.tsv -> subset_755.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_756.tsv -> subset_756.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_757.tsv -> subset_757.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_758.tsv -> subset_758.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_759.tsv -> subset_759.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_760.tsv -> subset_760.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_761.tsv -> subset_761.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_762.tsv -> subset_762.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_763.tsv -> subset_763.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_764.tsv -> subset_764.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_765.tsv -> subset_765.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_766.tsv -> subset_766.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_767.tsv -> subset_767.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_768.tsv -> subset_768.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_769.tsv -> subset_769.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_770.tsv -> subset_770.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_771.tsv -> subset_771.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_772.tsv -> subset_772.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_773.tsv -> subset_773.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_774.tsv -> subset_774.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_775.tsv -> subset_775.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_776.tsv -> subset_776.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_777.tsv -> subset_777.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_778.tsv -> subset_778.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_779.tsv -> subset_779.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_780.tsv -> subset_780.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_781.tsv -> subset_781.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_782.tsv -> subset_782.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_783.tsv -> subset_783.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_784.tsv -> subset_784.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_785.tsv -> subset_785.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_786.tsv -> subset_786.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_787.tsv -> subset_787.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_788.tsv -> subset_788.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_789.tsv -> subset_789.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_790.tsv -> subset_790.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_791.tsv -> subset_791.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_792.tsv -> subset_792.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_793.tsv -> subset_793.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_794.tsv -> subset_794.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_795.tsv -> subset_795.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_796.tsv -> subset_796.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_797.tsv -> subset_797.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_798.tsv -> subset_798.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_799.tsv -> subset_799.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_800.tsv -> subset_800.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_801.tsv -> subset_801.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_802.tsv -> subset_802.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_803.tsv -> subset_803.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_804.tsv -> subset_804.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_805.tsv -> subset_805.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_806.tsv -> subset_806.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_807.tsv -> subset_807.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_808.tsv -> subset_808.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_809.tsv -> subset_809.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_810.tsv -> subset_810.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_811.tsv -> subset_811.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_812.tsv -> subset_812.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_813.tsv -> subset_813.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_814.tsv -> subset_814.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_815.tsv -> subset_815.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_816.tsv -> subset_816.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_817.tsv -> subset_817.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_818.tsv -> subset_818.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_819.tsv -> subset_819.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_820.tsv -> subset_820.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_821.tsv -> subset_821.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_822.tsv -> subset_822.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_823.tsv -> subset_823.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_824.tsv -> subset_824.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_825.tsv -> subset_825.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_826.tsv -> subset_826.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_827.tsv -> subset_827.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_828.tsv -> subset_828.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_829.tsv -> subset_829.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_830.tsv -> subset_830.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_831.tsv -> subset_831.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_832.tsv -> subset_832.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_833.tsv -> subset_833.reaction_features_drf_wl_h3.pkl
# [+] Precomputing subset_834.tsv -> subset_834.reaction_features_drf_wl_h3.pkl
# [✓] Done.
