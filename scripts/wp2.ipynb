# %%
from wp2_functions import drf_features_from_rsmi, drf_wl_features_from_rsmi, plot_wl_drf_iterations_from_rsmi, wl_feature_sets_per_iter_graph, drf_wl_features_per_iter_from_rsmi, plot_wl_drf_feature_growth_from_rsmi
import pandas as pd
from vis_utils import plot_drf_from_counters_rsmi
import plotly.io as pio
from synkit.IO import rsmi_to_graph
pio.renderers.default = "vscode"

# %% [markdown]
# TODOs:
#
# 1. Implement transformations Φ for Vertex-, Edge- and Shortest-Path Labels.
# 2. Implement the DRF transformation function.
# 3. Implement Weisfeiler-Lehman with applications of Φ such that hashed feature sets are
# returned at every iteration.
# 4. Pre-compute feature hash sets for all datasets

# %%
# one rsmi for testing

path = "schneider50k_clean.tsv"
data = pd.read_csv(path, sep="\t")
rsmi = data["clean_rxn"].iloc[20]
print(rsmi)
# Out:
# [NH2:1][CH2:2][c:3]1[cH:33][cH:32][cH:31][c:5]([CH2:6][N:7]([CH2:20][c:21]2[cH:22][cH:23][c:24]([C:27]([F:28])([F:29])[F:30])[cH:25][cH:26]2)[S:8](=[O:9])(=[O:10])[c:11]2[cH:16][c:15]([Cl:17])[cH:14][c:13]([Cl:18])[c:12]2[OH:19])[cH:4]1.[O:44]=[C:43]=[N:42][c:36]1[cH:37][cH:38][c:39]([F:41])[cH:40][c:35]1[F:34]>>[O:44]=[C:43]([NH:1][CH2:2][c:3]1[cH:33][cH:32][cH:31][c:5]([CH2:6][N:7]([CH2:20][c:21]2[cH:26][cH:25][c:24]([C:27]([F:30])([F:28])[F:29])[cH:23][cH:22]2)[S:8](=[O:10])(=[O:9])[c:11]2[cH:16][c:15]([Cl:17])[cH:14][c:13]([Cl:18])[c:12]2[OH:19])[cH:4]1)[NH:42][c:36]1[cH:37][cH:38][c:39]([F:41])[cH:40][c:35]1[F:34]

# %% [markdown]
# ## 1. + 2. Implement transformations Φ for Vertex-, Edge- and Shortest-Path Labels + Implement the DRF transformation function.

# %% [markdown]
# In WP2, reactions are represented using **Differential Reaction Fingerprints (DRF)**.
# For a reaction \( R = (E_R, P_R) \), feature representations are first computed
# separately for the reactant graph \( \Phi(E_R) \) and the product graph \( \Phi(P_R) \).
#
# The reaction representation is then defined as the **symmetric difference**
# between these two feature multisets:
# \[
# \Phi_{\text{reaction}}(R) = \Phi(E_R) \,\Delta\, \Phi(P_R)
# \]
#
# This operation removes features that appear in both reactants and products
# and keeps only those features that change during the reaction.
# In this implementation, features are treated as **multisets** (using feature counts),
# so the symmetric difference is computed as the absolute difference of feature frequencies.
#
# Depending on the chosen mode, DRF can be constructed from
# vertex labels, edge labels, or shortest-path features.
# This representation focuses explicitly on structural changes
# and is used as input for kernel-based similarity computations in later steps.

# %% [markdown]
# → DRF filters out everything that does not belong to the reaction.
# → Only the change itself remains.

# %% [markdown]
# ### Comparing DRF Feature Types
#
# This cell computes Differential Reaction Fingerprints (DRF) using different base
# feature mappings (vertex labels, edge labels, and shortest paths).
# The resulting feature counts illustrate how the choice of Φ affects the richness
# and granularity of the reaction representation.

# %%
drf_E = drf_features_from_rsmi(rsmi, mode="edge")
drf_V = drf_features_from_rsmi(rsmi, mode="vertex")
drf_SP = drf_features_from_rsmi(rsmi, mode="sp", include_edge_labels_in_sp=True)

print("DRF edge feature count:", sum(drf_E.values()))
print("DRF vertex feature count:", sum(drf_V.values()))
print("DRF shortest-path feature count:", sum(drf_SP.values()))

# Optional: ein paar Einträge ansehen
print("Sample DRF edge items:", list(drf_E.items())[:10])
# Out:
# DRF edge feature count: 7
# DRF vertex feature count: 4
# DRF shortest-path feature count: 479
# Sample DRF edge items: [('dfece4a9dcd08795392ad70cc5917916', 1), ('de31134b08b96644d27409cf6bbb8a27', 1), ('c3597c2da4c3548b56a2e0db79dcb01f', 1), ('15f9e08649775a73900f08bfd014711b', 1), ('c39115617198efcb3b826afe5a16b5ca', 2), ('f7efcd62786774a9fdf164fdb955b257', 1)]

# %% [markdown]
# ### Visualizing DRF Features for Different Φ Mappings
#
# This cell visualizes the Differential Reaction Fingerprints derived from different
# base feature mappings (edge, vertex, and shortest-path features).
# Highlighted graph elements indicate structural differences between reactants and
# products that contribute to the DRF representation.

# %%
fig_e = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_E,
    mode="edge",
    hash_labels=True,              
    digest_size=16,                 
    show_edge_labels=True,
)
fig_e.show(renderer="vscode")

fig_v = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_V,
    mode="vertex",
    hash_labels=True,
    digest_size=16,
)
fig_v.show(renderer="vscode")

fig_sp = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_SP,
    mode="sp",
    include_edge_labels_in_sp=True, 
    hash_labels=True,
    digest_size=16,
)
fig_sp.show(renderer="vscode")

# %% [markdown]
# ## 3. Implement Weisfeiler-Lehman with applications of Φ such that hashed feature sets are returned at every iteration.

# %% [markdown]
# The Weisfeiler–Lehman (WL) algorithm iteratively refines node labels by incorporating
# the labels of neighboring nodes. Starting from initial node labels (e.g. atom types),
# each WL iteration constructs a new label for every node based on its current label
# and the multiset of its neighbors’ labels, followed by hashing.
#
# This process enriches node labels with increasingly larger local neighborhood
# information. After each iteration, feature maps Φ are applied to the relabeled graph
# and the resulting hashed feature sets are stored. These WL-enhanced features capture
# local substructures of the graph up to a given neighborhood depth and are later used
# for kernel-based similarity computations.
#
# → WL iteratively enriches node labels with neighborhood information, capturing increasingly complex local graph structures.
# → WL = wiederholtes Relabeling von Knoten anhand ihrer Nachbarschaft (und Hashing dieser neuen Labels).

# %% [markdown]
# ### WL-Enhanced DRF Feature Counts
#
# This cell computes Differential Reaction Fingerprints combined with Weisfeiler–Lehman
# (WL) relabeling for different base feature mappings (edge, vertex, and shortest paths).
# The printed counts summarize the total amount of structural change captured when
# neighborhood information up to WL depth h=3 is incorporated.

# %%
drf_wl_E = drf_wl_features_from_rsmi(rsmi, h=3, mode="edge")
drf_wl_V = drf_wl_features_from_rsmi(rsmi, h=3, mode="vertex")
drf_wl_SP = drf_wl_features_from_rsmi(rsmi, h=3, mode="sp", include_edge_labels_in_sp=True)
print(sum(drf_wl_E.values()), sum(drf_wl_V.values()), sum(drf_wl_SP.values()))
# Out:
# 80 60 2520

# %% [markdown]
# ### WL Feature Sets per Iteration
#
# This cell computes feature sets for a single graph after successive
# Weisfeiler–Lehman (WL) iterations.
# The printed values show how the number of extracted features grows with increasing
# WL depth, illustrating how neighborhood information is progressively incorporated.

# %%
ed, pr = rsmi_to_graph(rsmi)

sets_per_iter = wl_feature_sets_per_iter_graph(ed, h=3, mode="edge")  # Liste von Sets
print([len(s) for s in sets_per_iter])
# Out:
# [17, 32, 38, 40]

# %% [markdown]
# ### WL–DRF Features per Iteration and Visualization
#
# This cell computes WL-enhanced DRF features separately for each WL iteration and
# prints their total counts.
# The accompanying visualization highlights, for each iteration, which graph elements
# contribute to the DRF representation, illustrating how increasingly larger
# neighborhood information influences the detected reaction changes.
#
# Red graph elements indicate nodes or edges that contribute to the DRF representation, i.e. structural changes between reactants and products.
# (Rot markiert = das ist die Reaktion.
# Grau = chemisch irrelevant Hintergrund.)

# %%
per_iter, total = drf_wl_features_per_iter_from_rsmi(rsmi, h=3, mode="edge")
print([sum(c.values()) for c in per_iter], "sum:", sum(total.values()))


fig = plot_wl_drf_iterations_from_rsmi(rsmi, h=3, mode="edge", show_edge_labels=True)
fig.show()
# Out:
# [7, 15, 25, 33] sum: 80

# %% [markdown]
# ### WL–DRF Feature Growth Across Iterations
# This plot shows how the number and magnitude of DRF features evolve across WL iterations.
# It illustrates how successive WL relabeling steps introduce additional structural
# information until the representation saturates.

# %% [markdown]
# The WL-DRF feature growth shows that successive WL iterations introduce additional structural information. No saturation is observed up to h=3, indicating that deeper neighborhood information contributes meaningfully to the reaction representation.
# Das Diagramm zeigt, dass WL die DRF-Repräsentation schrittweise anreichert
# und bis Iteration 3 noch keine Sättigung erreicht ist.

# %%
fig = plot_wl_drf_feature_growth_from_rsmi(rsmi, h=3, mode="edge", show_cumulative=True)
fig.show()

# %% [markdown]
# ## Pre-computing Feature Hash Sets
#
# In this step, feature representations are pre-computed for all reactions in the dataset.
# For each reaction, hashed feature sets are generated using the previously defined
# DRF and WL–DRF transformations and stored for later use.
#
# This pre-computation avoids repeated and expensive feature extraction during kernel
# construction and enables efficient and reproducible experiments in subsequent work packages.

# %% [markdown]
# ### Pre-computing WL–DRF Feature Representations
#
# In this step, WL–DRF feature representations are pre-computed for all reactions in the
# selected datasets and stored on disk.
# This avoids repeated and expensive feature extraction and enables efficient kernel
# construction in subsequent work packages.
#
# precompute_all_subsets_in_dir speichert nicht die Reaktion,
# sondern die Änderung, die die Reaktion ausmacht.

# %%
from wp2_precompute_features import precompute_all_subsets_in_dir_drf_wl

out_dirs = ["drf/precomputed_drf_edge", "drf/precomputed_drf_vertex", "drf/precomputed_drf_sp"]

for dir in out_dirs:
    precompute_all_subsets_in_dir_drf_wl(
        subsets_dir="subsets_small",
        out_dir=dir,
        h=3,
        mode=dir.split("_")[-1],  # "edge", "vertex", or "sp"
    )
# Out:
# [+] DRF–WL precompute for subset_001.tsv
#     → saved to subset_001.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_002.tsv
#     → saved to subset_002.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_003.tsv
#     → saved to subset_003.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_004.tsv
#     → saved to subset_004.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_005.tsv
#     → saved to subset_005.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_006.tsv
#     → saved to subset_006.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_007.tsv
#     → saved to subset_007.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_008.tsv
#     → saved to subset_008.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_009.tsv
#     → saved to subset_009.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_010.tsv
#     → saved to subset_010.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_011.tsv
#     → saved to subset_011.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_012.tsv
#     → saved to subset_012.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_013.tsv
#     → saved to subset_013.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_014.tsv
#     → saved to subset_014.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_015.tsv
#     → saved to subset_015.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_016.tsv
#     → saved to subset_016.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_017.tsv
#     → saved to subset_017.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_018.tsv
#     → saved to subset_018.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_019.tsv
#     → saved to subset_019.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_020.tsv
#     → saved to subset_020.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_021.tsv
#     → saved to subset_021.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_022.tsv
#     → saved to subset_022.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_023.tsv
#     → saved to subset_023.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_024.tsv
#     → saved to subset_024.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_025.tsv
#     → saved to subset_025.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_026.tsv
#     → saved to subset_026.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_027.tsv
#     → saved to subset_027.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_028.tsv
#     → saved to subset_028.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_029.tsv
#     → saved to subset_029.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_030.tsv
#     → saved to subset_030.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_031.tsv
#     → saved to subset_031.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_032.tsv
#     → saved to subset_032.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_033.tsv
#     → saved to subset_033.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_034.tsv
#     → saved to subset_034.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_035.tsv
#     → saved to subset_035.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_036.tsv
#     → saved to subset_036.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_037.tsv
#     → saved to subset_037.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_038.tsv
#     → saved to subset_038.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_039.tsv
#     → saved to subset_039.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_040.tsv
#     → saved to subset_040.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_041.tsv
#     → saved to subset_041.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_042.tsv
#     → saved to subset_042.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_043.tsv
#     → saved to subset_043.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_044.tsv
#     → saved to subset_044.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_045.tsv
#     → saved to subset_045.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_046.tsv
#     → saved to subset_046.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_047.tsv
#     → saved to subset_047.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_048.tsv
#     → saved to subset_048.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_049.tsv
#     → saved to subset_049.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_050.tsv
#     → saved to subset_050.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_051.tsv
#     → saved to subset_051.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_052.tsv
#     → saved to subset_052.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_053.tsv
#     → saved to subset_053.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_054.tsv
#     → saved to subset_054.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_055.tsv
#     → saved to subset_055.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_056.tsv
#     → saved to subset_056.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_057.tsv
#     → saved to subset_057.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_058.tsv
#     → saved to subset_058.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_059.tsv
#     → saved to subset_059.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_060.tsv
#     → saved to subset_060.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_061.tsv
#     → saved to subset_061.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_062.tsv
#     → saved to subset_062.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_063.tsv
#     → saved to subset_063.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_064.tsv
#     → saved to subset_064.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_065.tsv
#     → saved to subset_065.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_066.tsv
#     → saved to subset_066.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_067.tsv
#     → saved to subset_067.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_068.tsv
#     → saved to subset_068.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_069.tsv
#     → saved to subset_069.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_070.tsv
#     → saved to subset_070.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_071.tsv
#     → saved to subset_071.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_072.tsv
#     → saved to subset_072.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_073.tsv
#     → saved to subset_073.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_074.tsv
#     → saved to subset_074.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_075.tsv
#     → saved to subset_075.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_076.tsv
#     → saved to subset_076.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_077.tsv
#     → saved to subset_077.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_078.tsv
#     → saved to subset_078.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_079.tsv
#     → saved to subset_079.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_080.tsv
#     → saved to subset_080.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_081.tsv
#     → saved to subset_081.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_082.tsv
#     → saved to subset_082.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_083.tsv
#     → saved to subset_083.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_084.tsv
#     → saved to subset_084.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_085.tsv
#     → saved to subset_085.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_086.tsv
#     → saved to subset_086.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_087.tsv
#     → saved to subset_087.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_088.tsv
#     → saved to subset_088.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_089.tsv
#     → saved to subset_089.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_090.tsv
#     → saved to subset_090.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_091.tsv
#     → saved to subset_091.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_092.tsv
#     → saved to subset_092.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_093.tsv
#     → saved to subset_093.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_094.tsv
#     → saved to subset_094.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_095.tsv
#     → saved to subset_095.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_096.tsv
#     → saved to subset_096.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_097.tsv
#     → saved to subset_097.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_098.tsv
#     → saved to subset_098.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_099.tsv
#     → saved to subset_099.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_100.tsv
#     → saved to subset_100.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_101.tsv
#     → saved to subset_101.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_102.tsv
#     → saved to subset_102.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_103.tsv
#     → saved to subset_103.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_104.tsv
#     → saved to subset_104.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_105.tsv
#     → saved to subset_105.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_106.tsv
#     → saved to subset_106.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_107.tsv
#     → saved to subset_107.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_108.tsv
#     → saved to subset_108.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_109.tsv
#     → saved to subset_109.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_110.tsv
#     → saved to subset_110.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_111.tsv
#     → saved to subset_111.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_112.tsv
#     → saved to subset_112.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_113.tsv
#     → saved to subset_113.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_114.tsv
#     → saved to subset_114.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_115.tsv
#     → saved to subset_115.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_116.tsv
#     → saved to subset_116.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_117.tsv
#     → saved to subset_117.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_118.tsv
#     → saved to subset_118.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_119.tsv
#     → saved to subset_119.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_120.tsv
#     → saved to subset_120.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_121.tsv
#     → saved to subset_121.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_122.tsv
#     → saved to subset_122.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_123.tsv
#     → saved to subset_123.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_124.tsv
#     → saved to subset_124.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_125.tsv
#     → saved to subset_125.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_126.tsv
#     → saved to subset_126.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_127.tsv
#     → saved to subset_127.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_128.tsv
#     → saved to subset_128.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_129.tsv
#     → saved to subset_129.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_130.tsv
#     → saved to subset_130.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_131.tsv
#     → saved to subset_131.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_132.tsv
#     → saved to subset_132.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_133.tsv
#     → saved to subset_133.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_134.tsv
#     → saved to subset_134.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_135.tsv
#     → saved to subset_135.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_136.tsv
#     → saved to subset_136.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_137.tsv
#     → saved to subset_137.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_138.tsv
#     → saved to subset_138.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_139.tsv
#     → saved to subset_139.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_140.tsv
#     → saved to subset_140.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_141.tsv
#     → saved to subset_141.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_142.tsv
#     → saved to subset_142.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_143.tsv
#     → saved to subset_143.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_144.tsv
#     → saved to subset_144.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_145.tsv
#     → saved to subset_145.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_146.tsv
#     → saved to subset_146.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_147.tsv
#     → saved to subset_147.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_148.tsv
#     → saved to subset_148.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_149.tsv
#     → saved to subset_149.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_150.tsv
#     → saved to subset_150.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_151.tsv
#     → saved to subset_151.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_152.tsv
#     → saved to subset_152.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_153.tsv
#     → saved to subset_153.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_154.tsv
#     → saved to subset_154.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_155.tsv
#     → saved to subset_155.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_156.tsv
#     → saved to subset_156.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_157.tsv
#     → saved to subset_157.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_158.tsv
#     → saved to subset_158.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_159.tsv
#     → saved to subset_159.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_160.tsv
#     → saved to subset_160.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_161.tsv
#     → saved to subset_161.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_162.tsv
#     → saved to subset_162.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_163.tsv
#     → saved to subset_163.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_164.tsv
#     → saved to subset_164.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_165.tsv
#     → saved to subset_165.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_166.tsv
#     → saved to subset_166.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_167.tsv
#     → saved to subset_167.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_168.tsv
#     → saved to subset_168.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_169.tsv
#     → saved to subset_169.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_170.tsv
#     → saved to subset_170.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_171.tsv
#     → saved to subset_171.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_172.tsv
#     → saved to subset_172.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_173.tsv
#     → saved to subset_173.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_174.tsv
#     → saved to subset_174.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_175.tsv
#     → saved to subset_175.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_176.tsv
#     → saved to subset_176.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_177.tsv
#     → saved to subset_177.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_178.tsv
#     → saved to subset_178.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_179.tsv
#     → saved to subset_179.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_180.tsv
#     → saved to subset_180.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_181.tsv
#     → saved to subset_181.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_182.tsv
#     → saved to subset_182.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_183.tsv
#     → saved to subset_183.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_184.tsv
#     → saved to subset_184.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_185.tsv
#     → saved to subset_185.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_186.tsv
#     → saved to subset_186.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_187.tsv
#     → saved to subset_187.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_188.tsv
#     → saved to subset_188.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_189.tsv
#     → saved to subset_189.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_190.tsv
#     → saved to subset_190.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_191.tsv
#     → saved to subset_191.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_192.tsv
#     → saved to subset_192.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_193.tsv
#     → saved to subset_193.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_194.tsv
#     → saved to subset_194.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_195.tsv
#     → saved to subset_195.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_196.tsv
#     → saved to subset_196.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_197.tsv
#     → saved to subset_197.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_198.tsv
#     → saved to subset_198.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_199.tsv
#     → saved to subset_199.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_200.tsv
#     → saved to subset_200.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_201.tsv
#     → saved to subset_201.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_202.tsv
#     → saved to subset_202.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_203.tsv
#     → saved to subset_203.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_204.tsv
#     → saved to subset_204.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_205.tsv
#     → saved to subset_205.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_206.tsv
#     → saved to subset_206.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_207.tsv
#     → saved to subset_207.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_208.tsv
#     → saved to subset_208.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_209.tsv
#     → saved to subset_209.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_210.tsv
#     → saved to subset_210.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_211.tsv
#     → saved to subset_211.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_212.tsv
#     → saved to subset_212.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_213.tsv
#     → saved to subset_213.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_214.tsv
#     → saved to subset_214.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_215.tsv
#     → saved to subset_215.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_216.tsv
#     → saved to subset_216.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_217.tsv
#     → saved to subset_217.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_218.tsv
#     → saved to subset_218.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_219.tsv
#     → saved to subset_219.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_220.tsv
#     → saved to subset_220.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_221.tsv
#     → saved to subset_221.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_222.tsv
#     → saved to subset_222.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_223.tsv
#     → saved to subset_223.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_224.tsv
#     → saved to subset_224.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_225.tsv
#     → saved to subset_225.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_226.tsv
#     → saved to subset_226.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_227.tsv
#     → saved to subset_227.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_228.tsv
#     → saved to subset_228.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_229.tsv
#     → saved to subset_229.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_230.tsv
#     → saved to subset_230.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_231.tsv
#     → saved to subset_231.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_232.tsv
#     → saved to subset_232.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_233.tsv
#     → saved to subset_233.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_234.tsv
#     → saved to subset_234.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_235.tsv
#     → saved to subset_235.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_236.tsv
#     → saved to subset_236.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_237.tsv
#     → saved to subset_237.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_238.tsv
#     → saved to subset_238.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_239.tsv
#     → saved to subset_239.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_240.tsv
#     → saved to subset_240.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_241.tsv
#     → saved to subset_241.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_242.tsv
#     → saved to subset_242.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_243.tsv
#     → saved to subset_243.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_244.tsv
#     → saved to subset_244.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_245.tsv
#     → saved to subset_245.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_246.tsv
#     → saved to subset_246.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_247.tsv
#     → saved to subset_247.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_248.tsv
#     → saved to subset_248.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_249.tsv
#     → saved to subset_249.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_250.tsv
#     → saved to subset_250.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_251.tsv
#     → saved to subset_251.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_252.tsv
#     → saved to subset_252.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_253.tsv
#     → saved to subset_253.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_254.tsv
#     → saved to subset_254.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_255.tsv
#     → saved to subset_255.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_256.tsv
#     → saved to subset_256.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_257.tsv
#     → saved to subset_257.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_258.tsv
#     → saved to subset_258.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_259.tsv
#     → saved to subset_259.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_260.tsv
#     → saved to subset_260.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_261.tsv
#     → saved to subset_261.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_262.tsv
#     → saved to subset_262.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_263.tsv
#     → saved to subset_263.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_264.tsv
#     → saved to subset_264.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_265.tsv
#     → saved to subset_265.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_266.tsv
#     → saved to subset_266.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_267.tsv
#     → saved to subset_267.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_268.tsv
#     → saved to subset_268.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_269.tsv
#     → saved to subset_269.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_270.tsv
#     → saved to subset_270.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_271.tsv
#     → saved to subset_271.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_272.tsv
#     → saved to subset_272.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_273.tsv
#     → saved to subset_273.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_274.tsv
#     → saved to subset_274.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_275.tsv
#     → saved to subset_275.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_276.tsv
#     → saved to subset_276.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_277.tsv
#     → saved to subset_277.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_278.tsv
#     → saved to subset_278.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_279.tsv
#     → saved to subset_279.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_280.tsv
#     → saved to subset_280.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_281.tsv
#     → saved to subset_281.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_282.tsv
#     → saved to subset_282.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_283.tsv
#     → saved to subset_283.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_284.tsv
#     → saved to subset_284.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_285.tsv
#     → saved to subset_285.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_286.tsv
#     → saved to subset_286.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_287.tsv
#     → saved to subset_287.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_288.tsv
#     → saved to subset_288.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_289.tsv
#     → saved to subset_289.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_290.tsv
#     → saved to subset_290.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_291.tsv
#     → saved to subset_291.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_292.tsv
#     → saved to subset_292.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_293.tsv
#     → saved to subset_293.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_294.tsv
#     → saved to subset_294.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_295.tsv
#     → saved to subset_295.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_296.tsv
#     → saved to subset_296.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_297.tsv
#     → saved to subset_297.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_298.tsv
#     → saved to subset_298.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_299.tsv
#     → saved to subset_299.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_300.tsv
#     → saved to subset_300.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_301.tsv
#     → saved to subset_301.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_302.tsv
#     → saved to subset_302.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_303.tsv
#     → saved to subset_303.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_304.tsv
#     → saved to subset_304.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_305.tsv
#     → saved to subset_305.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_306.tsv
#     → saved to subset_306.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_307.tsv
#     → saved to subset_307.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_308.tsv
#     → saved to subset_308.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_309.tsv
#     → saved to subset_309.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_310.tsv
#     → saved to subset_310.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_311.tsv
#     → saved to subset_311.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_312.tsv
#     → saved to subset_312.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_313.tsv
#     → saved to subset_313.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_314.tsv
#     → saved to subset_314.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_315.tsv
#     → saved to subset_315.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_316.tsv
#     → saved to subset_316.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_317.tsv
#     → saved to subset_317.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_318.tsv
#     → saved to subset_318.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_319.tsv
#     → saved to subset_319.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_320.tsv
#     → saved to subset_320.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_321.tsv
#     → saved to subset_321.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_322.tsv
#     → saved to subset_322.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_323.tsv
#     → saved to subset_323.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_324.tsv
#     → saved to subset_324.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_325.tsv
#     → saved to subset_325.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_326.tsv
#     → saved to subset_326.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_327.tsv
#     → saved to subset_327.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_328.tsv
#     → saved to subset_328.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_329.tsv
#     → saved to subset_329.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_330.tsv
#     → saved to subset_330.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_331.tsv
#     → saved to subset_331.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_332.tsv
#     → saved to subset_332.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_333.tsv
#     → saved to subset_333.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_334.tsv
#     → saved to subset_334.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_335.tsv
#     → saved to subset_335.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_336.tsv
#     → saved to subset_336.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_337.tsv
#     → saved to subset_337.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_338.tsv
#     → saved to subset_338.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_339.tsv
#     → saved to subset_339.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_340.tsv
#     → saved to subset_340.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_341.tsv
#     → saved to subset_341.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_342.tsv
#     → saved to subset_342.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_343.tsv
#     → saved to subset_343.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_344.tsv
#     → saved to subset_344.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_345.tsv
#     → saved to subset_345.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_346.tsv
#     → saved to subset_346.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_347.tsv
#     → saved to subset_347.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_348.tsv
#     → saved to subset_348.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_349.tsv
#     → saved to subset_349.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_350.tsv
#     → saved to subset_350.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_351.tsv
#     → saved to subset_351.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_352.tsv
#     → saved to subset_352.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_353.tsv
#     → saved to subset_353.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_354.tsv
#     → saved to subset_354.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_355.tsv
#     → saved to subset_355.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_356.tsv
#     → saved to subset_356.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_357.tsv
#     → saved to subset_357.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_358.tsv
#     → saved to subset_358.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_359.tsv
#     → saved to subset_359.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_360.tsv
#     → saved to subset_360.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_361.tsv
#     → saved to subset_361.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_362.tsv
#     → saved to subset_362.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_363.tsv
#     → saved to subset_363.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_364.tsv
#     → saved to subset_364.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_365.tsv
#     → saved to subset_365.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_366.tsv
#     → saved to subset_366.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_367.tsv
#     → saved to subset_367.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_368.tsv
#     → saved to subset_368.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_369.tsv
#     → saved to subset_369.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_370.tsv
#     → saved to subset_370.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_371.tsv
#     → saved to subset_371.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_372.tsv
#     → saved to subset_372.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_373.tsv
#     → saved to subset_373.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_374.tsv
#     → saved to subset_374.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_375.tsv
#     → saved to subset_375.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_376.tsv
#     → saved to subset_376.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_377.tsv
#     → saved to subset_377.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_378.tsv
#     → saved to subset_378.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_379.tsv
#     → saved to subset_379.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_380.tsv
#     → saved to subset_380.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_381.tsv
#     → saved to subset_381.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_382.tsv
#     → saved to subset_382.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_383.tsv
#     → saved to subset_383.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_384.tsv
#     → saved to subset_384.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_385.tsv
#     → saved to subset_385.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_386.tsv
#     → saved to subset_386.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_387.tsv
#     → saved to subset_387.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_388.tsv
#     → saved to subset_388.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_389.tsv
#     → saved to subset_389.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_390.tsv
#     → saved to subset_390.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_391.tsv
#     → saved to subset_391.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_392.tsv
#     → saved to subset_392.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_393.tsv
#     → saved to subset_393.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_394.tsv
#     → saved to subset_394.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_395.tsv
#     → saved to subset_395.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_396.tsv
#     → saved to subset_396.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_397.tsv
#     → saved to subset_397.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_398.tsv
#     → saved to subset_398.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_399.tsv
#     → saved to subset_399.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_400.tsv
#     → saved to subset_400.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_401.tsv
#     → saved to subset_401.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_402.tsv
#     → saved to subset_402.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_403.tsv
#     → saved to subset_403.reaction_features_drf_wl_h3_edge.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_404.tsv
# ...
# [+] DRF–WL precompute for subset_699.tsv
#     → saved to subset_699.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_700.tsv
#     → saved to subset_700.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_701.tsv
#     → saved to subset_701.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_702.tsv
#     → saved to subset_702.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_703.tsv
#     → saved to subset_703.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_704.tsv
#     → saved to subset_704.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_705.tsv
#     → saved to subset_705.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_706.tsv
#     → saved to subset_706.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_707.tsv
#     → saved to subset_707.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_708.tsv
#     → saved to subset_708.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_709.tsv
#     → saved to subset_709.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_710.tsv
#     → saved to subset_710.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_711.tsv
#     → saved to subset_711.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_712.tsv
#     → saved to subset_712.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_713.tsv
#     → saved to subset_713.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_714.tsv
#     → saved to subset_714.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_715.tsv
#     → saved to subset_715.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_716.tsv
#     → saved to subset_716.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_717.tsv
#     → saved to subset_717.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_718.tsv
#     → saved to subset_718.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_719.tsv
#     → saved to subset_719.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_720.tsv
#     → saved to subset_720.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_721.tsv
#     → saved to subset_721.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_722.tsv
#     → saved to subset_722.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_723.tsv
#     → saved to subset_723.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_724.tsv
#     → saved to subset_724.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_725.tsv
#     → saved to subset_725.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_726.tsv
#     → saved to subset_726.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_727.tsv
#     → saved to subset_727.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_728.tsv
#     → saved to subset_728.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_729.tsv
#     → saved to subset_729.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_730.tsv
#     → saved to subset_730.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_731.tsv
#     → saved to subset_731.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_732.tsv
#     → saved to subset_732.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_733.tsv
#     → saved to subset_733.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_734.tsv
#     → saved to subset_734.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_735.tsv
#     → saved to subset_735.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_736.tsv
#     → saved to subset_736.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_737.tsv
#     → saved to subset_737.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_738.tsv
#     → saved to subset_738.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_739.tsv
#     → saved to subset_739.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_740.tsv
#     → saved to subset_740.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_741.tsv
#     → saved to subset_741.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_742.tsv
#     → saved to subset_742.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_743.tsv
#     → saved to subset_743.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_744.tsv
#     → saved to subset_744.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_745.tsv
#     → saved to subset_745.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_746.tsv
#     → saved to subset_746.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_747.tsv
#     → saved to subset_747.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_748.tsv
#     → saved to subset_748.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_749.tsv
#     → saved to subset_749.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_750.tsv
#     → saved to subset_750.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_751.tsv
#     → saved to subset_751.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_752.tsv
#     → saved to subset_752.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_753.tsv
#     → saved to subset_753.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_754.tsv
#     → saved to subset_754.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_755.tsv
#     → saved to subset_755.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_756.tsv
#     → saved to subset_756.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_757.tsv
#     → saved to subset_757.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_758.tsv
#     → saved to subset_758.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_759.tsv
#     → saved to subset_759.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_760.tsv
#     → saved to subset_760.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_761.tsv
#     → saved to subset_761.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_762.tsv
#     → saved to subset_762.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_763.tsv
#     → saved to subset_763.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_764.tsv
#     → saved to subset_764.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_765.tsv
#     → saved to subset_765.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_766.tsv
#     → saved to subset_766.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_767.tsv
#     → saved to subset_767.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_768.tsv
#     → saved to subset_768.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_769.tsv
#     → saved to subset_769.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_770.tsv
#     → saved to subset_770.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_771.tsv
#     → saved to subset_771.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_772.tsv
#     → saved to subset_772.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_773.tsv
#     → saved to subset_773.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_774.tsv
#     → saved to subset_774.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_775.tsv
#     → saved to subset_775.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_776.tsv
#     → saved to subset_776.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_777.tsv
#     → saved to subset_777.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_778.tsv
#     → saved to subset_778.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_779.tsv
#     → saved to subset_779.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_780.tsv
#     → saved to subset_780.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_781.tsv
#     → saved to subset_781.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_782.tsv
#     → saved to subset_782.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_783.tsv
#     → saved to subset_783.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_784.tsv
#     → saved to subset_784.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_785.tsv
#     → saved to subset_785.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_786.tsv
#     → saved to subset_786.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_787.tsv
#     → saved to subset_787.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_788.tsv
#     → saved to subset_788.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_789.tsv
#     → saved to subset_789.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_790.tsv
#     → saved to subset_790.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_791.tsv
#     → saved to subset_791.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_792.tsv
#     → saved to subset_792.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_793.tsv
#     → saved to subset_793.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_794.tsv
#     → saved to subset_794.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_795.tsv
#     → saved to subset_795.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_796.tsv
#     → saved to subset_796.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_797.tsv
#     → saved to subset_797.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_798.tsv
#     → saved to subset_798.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_799.tsv
#     → saved to subset_799.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_800.tsv
#     → saved to subset_800.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_801.tsv
#     → saved to subset_801.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_802.tsv
#     → saved to subset_802.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_803.tsv
#     → saved to subset_803.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_804.tsv
#     → saved to subset_804.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_805.tsv
#     → saved to subset_805.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_806.tsv
#     → saved to subset_806.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_807.tsv
#     → saved to subset_807.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_808.tsv
#     → saved to subset_808.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_809.tsv
#     → saved to subset_809.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_810.tsv
#     → saved to subset_810.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_811.tsv
#     → saved to subset_811.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_812.tsv
#     → saved to subset_812.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_813.tsv
#     → saved to subset_813.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_814.tsv
#     → saved to subset_814.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_815.tsv
#     → saved to subset_815.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_816.tsv
#     → saved to subset_816.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_817.tsv
#     → saved to subset_817.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_818.tsv
#     → saved to subset_818.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_819.tsv
#     → saved to subset_819.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_820.tsv
#     → saved to subset_820.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_821.tsv
#     → saved to subset_821.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_822.tsv
#     → saved to subset_822.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_823.tsv
#     → saved to subset_823.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_824.tsv
#     → saved to subset_824.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_825.tsv
#     → saved to subset_825.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_826.tsv
#     → saved to subset_826.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_827.tsv
#     → saved to subset_827.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_828.tsv
#     → saved to subset_828.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_829.tsv
#     → saved to subset_829.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_830.tsv
#     → saved to subset_830.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_831.tsv
#     → saved to subset_831.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_832.tsv
#     → saved to subset_832.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_833.tsv
#     → saved to subset_833.reaction_features_drf_wl_h3_sp.pkl | errors: 0/60
# [+] DRF–WL precompute for subset_834.tsv
#     → saved to subset_834.reaction_features_drf_wl_h3_sp.pkl | errors: 0/20
# [✓] DRF–WL precompute finished.

# %%
from wp2_functions import (
    its_wl_feature_sets_per_iter_from_rsmi,
    its_final_hashset_SG_from_rsmi,
)

per_iter, total = its_wl_feature_sets_per_iter_from_rsmi(rsmi, h=3, mode="edge")
print("Features per iteration:", [len(c) for c in per_iter])
print("Total unique over all iterations:", len(total))

S_G = its_final_hashset_SG_from_rsmi(rsmi, h=3, mode="edge")
print("Final hashset S_G size:", len(S_G))

# %% [markdown]
# ### Vizualization of WL on ITS
# This visualization shows the effect of the Weisfeiler–Lehman algorithm on the ITS graph.
# The graph structure remains fixed, while node colors represent WL-refined labels at
# successive iterations, illustrating how increasing neighborhood context is encoded.

# %%
from vis_utils import visualize_its_wl_iterations

fig = visualize_its_wl_iterations(rsmi, h=3)
fig.show()

# %% [markdown]
# Node colors represent WL labels.
# At iteration 0, nodes are colored by atom type only.
# At iteration 1, colors encode the immediate neighborhood of each atom.
# At iteration 2, colors further distinguish atoms based on the neighborhood of their neighbors,
# illustrating how increasing structural context is incorporated.

# %% [markdown]
# ### ITS–WL Feature Growth Across Iterations
# This plot shows how the number of ITS–WL features evolves across WL iterations.
# It illustrates how increasing neighborhood depth enriches the ITS representation
# until the feature set saturates.

# %%
from wp2_functions import plot_its_wl_feature_growth_from_rsmi
fig = plot_its_wl_feature_growth_from_rsmi(rsmi, h=3, mode="edge")
fig.show()

# %% [markdown]
# While the previous plot illustrates feature growth for a single reaction,
# the following analysis aggregates ITS–WL feature counts across an entire subset.
# Averaging over multiple reactions provides a more robust view of how the WL
# representation typically evolves with increasing iteration depth.

# %% [markdown]
# ### ITS–WL Feature Growth Across Iterations (Subset Average)
#
# This plot shows the average growth of ITS–WL feature counts across WL iterations,
# aggregated over all reactions in a subset. Averaging across multiple reactions
# provides a robust view of how structural context is progressively captured by
# the WL procedure and whether feature growth saturates with increasing depth.

# %%
from wp2_functions import plot_its_wl_feature_growth_subset

subset_df = data.iloc[:20]
fig = plot_its_wl_feature_growth_subset(
    subset_df,   # z.B. ein DataFrame aus subsets_small
    h=3,
    mode="edge",
)
fig.show()

# %% [markdown]
# ## Pre-computing ITS–WL Feature Representations
#
# In this step, WL-based feature representations are pre-computed for the Imaginary
# Transition State (ITS) graphs of all reactions in the selected subsets.
# For each reaction, features are extracted across all Weisfeiler–Lehman iterations
# and aggregated into a single representation, which is stored for later kernel-based
# classification.

# %%
from wp2_precompute_features import precompute_all_subsets_in_dir_its_wl

out_dirs = ["its/precomputed_its_edge", "its/precomputed_its_vertex", "its/precomputed_its_sp"]

for dir in out_dirs:
    precompute_all_subsets_in_dir_its_wl(
        subsets_dir="subsets_small",
        out_dir=dir,
        h=3,
        mode=dir.split("_")[-1],  # "edge", "vertex", or "sp"
    )

# %% [markdown]
# ## Comparison of ITS–WL and DRF–WL Representations
#
# The following visualizations compare two WL-based reaction representations.
# The ITS–WL view applies Weisfeiler–Lehman relabeling to the Imaginary Transition State
# graph, illustrating how structural context is refined across iterations.
# In contrast, the DRF–WL visualization highlights graph elements that contribute to the
# reaction difference between reactants and products, thereby localizing the reaction
# center and its surrounding context.
#
# ITS–WL encodes structural context,
# DRF–WL localizes reaction-specific changes.

# %% [markdown]
# ### ITS–WL vs DRF–WL Feature Growth Across Iterations
#
# This plot compares how feature sets evolve across WL iterations for two reaction
# representations: ITS–WL (single reaction graph) and DRF–WL (difference between
# reactants and products). Aggregating over a subset provides a robust view of how
# quickly structural context is captured and whether feature growth saturates.

# %%
subset_df = pd.read_csv("subsets_small/subset_001.tsv", sep="\t")
# oder: subset_df = data.iloc[:60]

from wp2_functions import plot_feature_growth_subset_its_vs_drf
fig = plot_feature_growth_subset_its_vs_drf(subset_df, h=3, mode="edge", show_errorbars=True)
fig.show()

# %% [markdown]
# The plot shows the average growth of WL-based feature sets across iterations for two
# reaction representations: ITS–WL and DRF–WL.
# For ITS–WL, features are extracted from a single reaction graph, and their number
# increases steadily as larger structural neighborhoods are incorporated.
# In contrast, DRF–WL focuses on differences between reactants and products, resulting
# in a more compact feature set that grows more slowly and saturates earlier.
# This comparison illustrates that ITS–WL captures global structural context, whereas
# DRF–WL emphasizes reaction-specific changes and their local environment.
#
# ITS–WL wächst, weil es Struktur beschreibt.
# DRF–WL wächst langsamer, weil es nur Änderung beschreibt.

# %% [markdown]
# ### Kernel overlap sanity check (DRF–WL)
#
# To verify that the DRF–WL representation is useful for a kernel method, we measure how often two reactions share at least one feature (non-zero kernel value).
# For \(n=50\) reactions, about 23% of all pairs have non-zero overlap, while the median similarity is 0 due to the sparsity of DRF features. This indicates a sparse but informative kernel signal.

# %%
import numpy as np
from scripts.wp3_kernel_old import kernel_multiset_intersection
from wp2_functions import drf_wl_features_from_rsmi

# n klein halten für Speed
n = 50
F = [drf_wl_features_from_rsmi(data["clean_rxn"].iloc[i], h=3, mode="edge") for i in range(n)]

vals = []
for i in range(n):
    for j in range(i+1, n):
        vals.append(kernel_multiset_intersection(F[i], F[j]))

vals = np.array(vals)
print("Pairs:", len(vals))
print("Non-zero pairs:", (vals > 0).sum())
print("Share non-zero:", (vals > 0).mean())
print("Max:", vals.max(), "Median:", np.median(vals), "Mean:", vals.mean())
