# %%
from pathlib import Path
import sys

ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents] if (p / "scripts").is_dir() or (p / "data").is_dir()), None)
if ROOT is None:
    raise RuntimeError("Repo-Root not found (expected folder 'scripts' or 'data').")
sys.path.insert(0, str(ROOT))
DATA_DIR = ROOT / "data"

# Eingabe- und Ausgabe-Verzeichnisse unter DATA_DIR
subsets_dir_big = DATA_DIR / "subsets_big"
subsets_dir_small = DATA_DIR / "subsets_small"
assert subsets_dir_big.exists(), f"Input dir missing: {subsets_dir_big}"
assert subsets_dir_small.exists(), f"Input dir missing: {subsets_dir_small}"

targets_big_drf = [(DATA_DIR / "drf_big" / f"precomputed_drf_{m}", m) for m in ("edge", "vertex", "sp")]
targets_small_drf = [(DATA_DIR / "drf_small" / f"precomputed_drf_{m}", m) for m in ("edge", "vertex", "sp")]
targets_big_its = [(DATA_DIR / "its_big" / f"precomputed_its_{m}", m) for m in ("edge", "vertex", "sp")]
targets_small_its = [(DATA_DIR / "its_small" / f"precomputed_its_{m}", m) for m in ("edge", "vertex", "sp")]

# %%
import pandas as pd
import plotly.io as pio
pio.renderers.default = "vscode"
from synkit.IO import rsmi_to_graph

#local imports
from scripts.wp2.wp2_functions import (
    drf_features_from_rsmi, 
    drf_wl_features_from_rsmi, 
    plot_wl_drf_iterations_from_rsmi, 
    wl_feature_sets_per_iter_graph, 
    drf_wl_features_per_iter_from_rsmi, 
    plot_wl_drf_feature_growth_from_rsmi,
    its_wl_feature_sets_per_iter_from_rsmi,
    its_final_hashset_SG_from_rsmi,
    plot_its_wl_feature_growth_from_rsmi,
    plot_its_wl_feature_growth_subset,
    plot_feature_growth_subset_its_vs_drf
)
from scripts.vis_utils import (
    plot_drf_from_counters_rsmi,
    visualize_its_wl_iterations)
from scripts.wp2.wp2_precompute_features import (
    precompute_all_subsets_in_dir_drf_wl,
    precompute_all_subsets_in_dir_its_wl)

# %% [markdown]
# TODOs:
#
# 1. Implement transformations Φ for Vertex-, Edge- and Shortest-Path Labels.
# 2. Implement the DRF transformation function.
# 3. Implement Weisfeiler-Lehman with applications of Φ such that hashed feature sets are
# returned at every iteration.
# 4. Pre-compute feature hash sets for all datasets

# %%
# one rsmi for testing

path = DATA_DIR / "schneider50k_clean.tsv"
data = pd.read_csv(path, sep="\t")
rsmi = data["clean_rxn"].iloc[20]
print(rsmi)
# Out:
# [NH2:1][CH2:2][c:3]1[cH:33][cH:32][cH:31][c:5]([CH2:6][N:7]([CH2:20][c:21]2[cH:22][cH:23][c:24]([C:27]([F:28])([F:29])[F:30])[cH:25][cH:26]2)[S:8](=[O:9])(=[O:10])[c:11]2[cH:16][c:15]([Cl:17])[cH:14][c:13]([Cl:18])[c:12]2[OH:19])[cH:4]1.[O:44]=[C:43]=[N:42][c:36]1[cH:37][cH:38][c:39]([F:41])[cH:40][c:35]1[F:34]>>[O:44]=[C:43]([NH:1][CH2:2][c:3]1[cH:33][cH:32][cH:31][c:5]([CH2:6][N:7]([CH2:20][c:21]2[cH:26][cH:25][c:24]([C:27]([F:30])([F:28])[F:29])[cH:23][cH:22]2)[S:8](=[O:10])(=[O:9])[c:11]2[cH:16][c:15]([Cl:17])[cH:14][c:13]([Cl:18])[c:12]2[OH:19])[cH:4]1)[NH:42][c:36]1[cH:37][cH:38][c:39]([F:41])[cH:40][c:35]1[F:34]

# %% [markdown]
# ## 1. + 2. Implement transformations Φ for Vertex-, Edge- and Shortest-Path Labels + Implement the DRF transformation function.

# %% [markdown]
# In WP2, reactions are represented using **Differential Reaction Fingerprints (DRF)**.
# For a reaction \( R = (E_R, P_R) \), feature representations are first computed
# separately for the reactant graph \( \Phi(E_R) \) and the product graph \( \Phi(P_R) \).
#
# The reaction representation is then defined as the **symmetric difference**
# between these two feature multisets:
# \[
# \Phi_{\text{reaction}}(R) = \Phi(E_R) \,\Delta\, \Phi(P_R)
# \]
#
# This operation removes features that appear in both reactants and products
# and keeps only those features that change during the reaction.
# In this implementation, features are treated as **multisets** (using feature counts),
# so the symmetric difference is computed as the absolute difference of feature frequencies.
#
# Depending on the chosen mode, DRF can be constructed from
# vertex labels, edge labels, or shortest-path features.
# This representation focuses explicitly on structural changes
# and is used as input for kernel-based similarity computations in later steps.

# %% [markdown]
# → DRF filters out everything that does not belong to the reaction.
# → Only the change itself remains.

# %% [markdown]
# ### Comparing DRF Feature Types
#
# This cell computes Differential Reaction Fingerprints (DRF) using different base
# feature mappings (vertex labels, edge labels, and shortest paths).
# The resulting feature counts illustrate how the choice of Φ affects the richness
# and granularity of the reaction representation.

# %%
drf_E = drf_features_from_rsmi(rsmi, mode="edge")
drf_V = drf_features_from_rsmi(rsmi, mode="vertex")
drf_SP = drf_features_from_rsmi(rsmi, mode="sp", include_edge_labels_in_sp=True)

print("DRF edge feature count:", sum(drf_E.values()))
print("DRF vertex feature count:", sum(drf_V.values()))
print("DRF shortest-path feature count:", sum(drf_SP.values()))

# Optional: ein paar Einträge ansehen
print("Sample DRF edge items:", list(drf_E.items())[:10])
# Out:
# DRF edge feature count: 7
# DRF vertex feature count: 4
# DRF shortest-path feature count: 479
# Sample DRF edge items: [('c39115617198efcb3b826afe5a16b5ca', 2), ('f7efcd62786774a9fdf164fdb955b257', 1), ('c3597c2da4c3548b56a2e0db79dcb01f', 1), ('dfece4a9dcd08795392ad70cc5917916', 1), ('15f9e08649775a73900f08bfd014711b', 1), ('de31134b08b96644d27409cf6bbb8a27', 1)]

# %% [markdown]
# ### Visualizing DRF Features for Different Φ Mappings
#
# This cell visualizes the Differential Reaction Fingerprints derived from different
# base feature mappings (edge, vertex, and shortest-path features).
# Highlighted graph elements indicate structural differences between reactants and
# products that contribute to the DRF representation.

# %%
fig_e = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_E,
    mode="edge",
    hash_labels=True,              
    digest_size=16,                 
    show_edge_labels=True,
)
fig_e.show(renderer="vscode")

fig_v = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_V,
    mode="vertex",
    hash_labels=True,
    digest_size=16,
)
fig_v.show(renderer="vscode")

fig_sp = plot_drf_from_counters_rsmi(
    rsmi,
    drf_counter=drf_SP,
    mode="sp",
    include_edge_labels_in_sp=True, 
    hash_labels=True,
    digest_size=16,
)
fig_sp.show(renderer="vscode")

# %% [markdown]
# ## 3. Implement Weisfeiler-Lehman with applications of Φ such that hashed feature sets are returned at every iteration.

# %% [markdown]
# The Weisfeiler–Lehman (WL) algorithm iteratively refines node labels by incorporating
# the labels of neighboring nodes. Starting from initial node labels (e.g. atom types),
# each WL iteration constructs a new label for every node based on its current label
# and the multiset of its neighbors’ labels, followed by hashing.
#
# This process enriches node labels with increasingly larger local neighborhood
# information. After each iteration, feature maps Φ are applied to the relabeled graph
# and the resulting hashed feature sets are stored. These WL-enhanced features capture
# local substructures of the graph up to a given neighborhood depth and are later used
# for kernel-based similarity computations.
#
# → WL iteratively enriches node labels with neighborhood information, capturing increasingly complex local graph structures.
# → WL = wiederholtes Relabeling von Knoten anhand ihrer Nachbarschaft (und Hashing dieser neuen Labels).

# %% [markdown]
# ### WL-Enhanced DRF Feature Counts
#
# This cell computes Differential Reaction Fingerprints combined with Weisfeiler–Lehman
# (WL) relabeling for different base feature mappings (edge, vertex, and shortest paths).
# The printed counts summarize the total amount of structural change captured when
# neighborhood information up to WL depth h=3 is incorporated.

# %%
drf_wl_E = drf_wl_features_from_rsmi(rsmi, h=3, mode="edge")
drf_wl_V = drf_wl_features_from_rsmi(rsmi, h=3, mode="vertex")
drf_wl_SP = drf_wl_features_from_rsmi(rsmi, h=3, mode="sp", include_edge_labels_in_sp=True)
print(sum(drf_wl_E.values()), sum(drf_wl_V.values()), sum(drf_wl_SP.values()))
# Out:
# 80 60 2520

# %% [markdown]
# ### WL Feature Sets per Iteration
#
# This cell computes feature sets for a single graph after successive
# Weisfeiler–Lehman (WL) iterations.
# The printed values show how the number of extracted features grows with increasing
# WL depth, illustrating how neighborhood information is progressively incorporated.

# %%
ed, pr = rsmi_to_graph(rsmi)

sets_per_iter = wl_feature_sets_per_iter_graph(ed, h=3, mode="edge")  # Liste von Sets
print([len(s) for s in sets_per_iter])
# Out:
# [17, 32, 38, 40]

# %% [markdown]
# ### WL–DRF Features per Iteration and Visualization
#
# This cell computes WL-enhanced DRF features separately for each WL iteration and
# prints their total counts.
# The accompanying visualization highlights, for each iteration, which graph elements
# contribute to the DRF representation, illustrating how increasingly larger
# neighborhood information influences the detected reaction changes.
#
# Red graph elements indicate nodes or edges that contribute to the DRF representation, i.e. structural changes between reactants and products.
# (Rot markiert = das ist die Reaktion.
# Grau = chemisch irrelevant Hintergrund.)

# %%
per_iter, total = drf_wl_features_per_iter_from_rsmi(rsmi, h=3, mode="edge")
print([sum(c.values()) for c in per_iter], "sum:", sum(total.values()))


fig = plot_wl_drf_iterations_from_rsmi(rsmi, h=3, mode="edge", show_edge_labels=True)
fig.show()
# Out:
# [7, 15, 25, 33] sum: 80

# %% [markdown]
# ### WL–DRF Feature Growth Across Iterations
# This plot shows how the number and magnitude of DRF features evolve across WL iterations.
# It illustrates how successive WL relabeling steps introduce additional structural
# information until the representation saturates.

# %% [markdown]
# The WL-DRF feature growth shows that successive WL iterations introduce additional structural information. No saturation is observed up to h=3, indicating that deeper neighborhood information contributes meaningfully to the reaction representation.
# Das Diagramm zeigt, dass WL die DRF-Repräsentation schrittweise anreichert
# und bis Iteration 3 noch keine Sättigung erreicht ist.

# %%
fig = plot_wl_drf_feature_growth_from_rsmi(rsmi, h=3, mode="edge", show_cumulative=True)
fig.show()

# %% [markdown]
# ## Pre-computing Feature Hash Sets
#
# In this step, feature representations are pre-computed for all reactions in the dataset.
# For each reaction, hashed feature sets are generated using the previously defined
# DRF and WL–DRF transformations and stored for later use.
#
# This pre-computation avoids repeated and expensive feature extraction during kernel
# construction and enables efficient and reproducible experiments in subsequent work packages.

# %% [markdown]
# ### Pre-computing WL–DRF Feature Representations
#
# In this step, WL–DRF feature representations are pre-computed for all reactions in the
# selected datasets and stored on disk.
# This avoids repeated and expensive feature extraction and enables efficient kernel
# construction in subsequent work packages.
#
# precompute_all_subsets_in_dir speichert nicht die Reaktion,
# sondern die Änderung, die die Reaktion ausmacht.

# %%
for out_dir, mode in targets_big_drf:
    out_dir.mkdir(parents=True, exist_ok=True)  
    print(f"write to {out_dir} (mode={mode})")
    precompute_all_subsets_in_dir_drf_wl(
        subsets_dir=str(subsets_dir_big), 
        out_dir=str(out_dir),
        h=3,
        mode=mode,  # "edge" | "vertex" | "sp"
    )
# Out:
# write to c:\Users\OPokrovskaja\Documents\praktikum_graphen\reaction-kernels\data\drf_big\precomputed_drf_edge (mode=edge)
# [+] DRF–WL precompute for subset_001.tsv
#     → saved to subset_001.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_002.tsv
#     → saved to subset_002.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_003.tsv
#     → saved to subset_003.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_004.tsv
#     → saved to subset_004.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_005.tsv
#     → saved to subset_005.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_006.tsv
#     → saved to subset_006.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_007.tsv
#     → saved to subset_007.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_008.tsv
#     → saved to subset_008.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_009.tsv
#     → saved to subset_009.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_010.tsv
#     → saved to subset_010.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_011.tsv
#     → saved to subset_011.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_012.tsv
#     → saved to subset_012.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_013.tsv
#     → saved to subset_013.reaction_features_drf_wl_h3_edge.pkl | errors: 0/1000
# [+] DRF–WL precompute for subset_014.tsv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       2 out_dir.mkdir(parents=True, exist_ok=True)
#       3 print(f"write to {out_dir} (mode={mode})")
# ----> 4 precompute_all_subsets_in_dir_drf_wl(
#       5     subsets_dir=str(subsets_dir_big),
#       6     out_dir=str(out_dir),
#       7     h=3,
#       8     mode=mode,  # "edge" | "vertex" | "sp"
#       9 )
#
# File c:\Users\OPokrovskaja\Documents\praktikum_graphen\reaction-kernels\scripts\wp2\wp2_precompute_features.py:250, in precompute_all_subsets_in_dir_drf_wl(subsets_dir, out_dir, rxn_col, class_col, pattern, h, mode, include_edge_labels_in_sp, hash_node_labels, hash_features, digest_size)
#     247 for idx, rsmi in enumerate(df[rxn_col].astype(str)):
#     248     try:
#     249         # ✅ FIX: drf_wl_features_from_rsmi returns ONE Counter
# --> 250         total = drf_wl_features_from_rsmi(
#     251             rsmi,
#     252             h=h,
#     253             mode=mode,
#     254             include_edge_labels_in_sp=include_edge_labels_in_sp,
#     255             hash_node_labels=hash_node_labels,
#     256             hash_features=hash_features,
#     257             digest_size=digest_size,
#     258         )
#     259         features.append(total)
#     261     except Exception as e:
#
# File c:\Users\OPokrovskaja\Documents\praktikum_graphen\reaction-kernels\scripts\wp2\wp2_functions.py:413, in drf_wl_features_from_rsmi(rsmi, h, mode, include_edge_labels_in_sp, hash_node_labels, hash_features, digest_size)
#     411 from synkit.IO import rsmi_to_graph
#     412 ed, pr = rsmi_to_educt_product(rsmi)
# --> 413 return drf_wl_features_from_graphs(
#     414     ed, pr,
#     415     h=h,
#     416     mode=mode,
#     417     include_edge_labels_in_sp=include_edge_labels_in_sp,
#     418     hash_node_labels=hash_node_labels,
#     419     hash_features=hash_features,
#     420     digest_size=digest_size,
#     421 )
#
# File c:\Users\OPokrovskaja\Documents\praktikum_graphen\reaction-kernels\scripts\wp2\wp2_functions.py:375, in drf_wl_features_from_graphs(educt_graph, product_graph, h, mode, include_edge_labels_in_sp, hash_node_labels, hash_features, digest_size)
#     367 """
#     368 DRF mit WL über h Iterationen:
#     369   - L^0..L^h für Edukt & Produkt
#    (...)    372   - aufsummieren über i=0..h
#     373 """
#     374 ed_seq = wl_label_sequence(educt_graph, h, hash_node_labels=hash_node_labels, digest_size=digest_size)
# --> 375 pr_seq = wl_label_sequence(product_graph, h, hash_node_labels=hash_node_labels, digest_size=digest_size)
#     377 total = Counter()
#     378 for i in range(h + 1):
#
# File c:\Users\OPokrovskaja\Documents\praktikum_graphen\reaction-kernels\scripts\wp2\wp2_functions.py:267, in wl_label_sequence(G, h, hash_node_labels, digest_size)
#     261 """
#     262 Erzeuge die Sequenz L^0..L^h der WL-Knotenlabels.
#     263 L^0(u) kommt aus get_node_label(G,u) (optional gehasht).
#     264 L^{t+1}(u) = hash( L^t(u) | sort([L^t(v) for v in N(u)]) ).
#     265 """
#     266 # L0
# --> 267 L0: Dict[Any, str] = {n: str(get_node_label(G, n)) for n in G.nodes()}
#     268 if hash_node_labels:
#     269     L0 = {n: _hash_str(lbl, digest_size) for n, lbl in L0.items()}
#
# KeyboardInterrupt:

# %%
for out_dir, mode in targets_small_drf:
    out_dir.mkdir(parents=True, exist_ok=True)  
    print(f"write to {out_dir} (mode={mode})")
    precompute_all_subsets_in_dir_drf_wl(
        subsets_dir=str(subsets_dir_small), 
        out_dir=str(out_dir),
        h=3,
        mode=mode,  # "edge" | "vertex" | "sp"
    )

# %%
per_iter, total = its_wl_feature_sets_per_iter_from_rsmi(rsmi, h=3, mode="edge")
print("Features per iteration:", [len(c) for c in per_iter])
print("Total unique over all iterations:", len(total))

S_G = its_final_hashset_SG_from_rsmi(rsmi, h=3, mode="edge")
print("Final hashset S_G size:", len(S_G))
# Out:
# Features per iteration: [12, 24, 35, 39]
# Total unique over all iterations: 110
# Final hashset S_G size: 110

# %% [markdown]
# ### Vizualization of WL on ITS
# This visualization shows the effect of the Weisfeiler–Lehman algorithm on the ITS graph.
# The graph structure remains fixed, while node colors represent WL-refined labels at
# successive iterations, illustrating how increasing neighborhood context is encoded.

# %%
fig = visualize_its_wl_iterations(rsmi, h=3)
fig.show()

# %% [markdown]
# Node colors represent WL labels.
# At iteration 0, nodes are colored by atom type only.
# At iteration 1, colors encode the immediate neighborhood of each atom.
# At iteration 2, colors further distinguish atoms based on the neighborhood of their neighbors,
# illustrating how increasing structural context is incorporated.

# %% [markdown]
# ### ITS–WL Feature Growth Across Iterations
# This plot shows how the number of ITS–WL features evolves across WL iterations.
# It illustrates how increasing neighborhood depth enriches the ITS representation
# until the feature set saturates.

# %%
fig = plot_its_wl_feature_growth_from_rsmi(rsmi, h=3, mode="edge")
fig.show()

# %% [markdown]
# While the previous plot illustrates feature growth for a single reaction,
# the following analysis aggregates ITS–WL feature counts across an entire subset.
# Averaging over multiple reactions provides a more robust view of how the WL
# representation typically evolves with increasing iteration depth.

# %% [markdown]
# ### ITS–WL Feature Growth Across Iterations (Subset Average)
#
# This plot shows the average growth of ITS–WL feature counts across WL iterations,
# aggregated over all reactions in a subset. Averaging across multiple reactions
# provides a robust view of how structural context is progressively captured by
# the WL procedure and whether feature growth saturates with increasing depth.

# %%
subset_df = data.iloc[:20]
fig = plot_its_wl_feature_growth_subset(
    subset_df,   # z.B. ein DataFrame aus subsets_small
    h=3,
    mode="edge",
)
fig.show()

# %% [markdown]
# ## Pre-computing ITS–WL Feature Representations
#
# In this step, WL-based feature representations are pre-computed for the Imaginary
# Transition State (ITS) graphs of all reactions in the selected subsets.
# For each reaction, features are extracted across all Weisfeiler–Lehman iterations
# and aggregated into a single representation, which is stored for later kernel-based
# classification.

# %%
for out_dir, mode in targets_small_its:
    out_dir.mkdir(parents=True, exist_ok=True)  
    print(f"write to {out_dir} (mode={mode})")
    precompute_all_subsets_in_dir_drf_wl(
        subsets_dir=str(subsets_dir_small), 
        out_dir=str(out_dir),
        h=3,
        mode=mode,  # "edge" | "vertex" | "sp"
    )
# Out:
# [+] ITS–WL precompute for subset_001.tsv
#     → saved to subset_001.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_002.tsv
#     → saved to subset_002.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_003.tsv
#     → saved to subset_003.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_004.tsv
#     → saved to subset_004.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_005.tsv
#     → saved to subset_005.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_006.tsv
#     → saved to subset_006.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_007.tsv
#     → saved to subset_007.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_008.tsv
#     → saved to subset_008.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_009.tsv
#     → saved to subset_009.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_010.tsv
#     → saved to subset_010.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_011.tsv
#     → saved to subset_011.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_012.tsv
#     → saved to subset_012.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_013.tsv
#     → saved to subset_013.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_014.tsv
#     → saved to subset_014.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_015.tsv
#     → saved to subset_015.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_016.tsv
#     → saved to subset_016.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_017.tsv
#     → saved to subset_017.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_018.tsv
#     → saved to subset_018.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_019.tsv
#     → saved to subset_019.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_020.tsv
#     → saved to subset_020.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_021.tsv
#     → saved to subset_021.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_022.tsv
#     → saved to subset_022.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_023.tsv
#     → saved to subset_023.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_024.tsv
#     → saved to subset_024.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_025.tsv
#     → saved to subset_025.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_026.tsv
#     → saved to subset_026.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_027.tsv
#     → saved to subset_027.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_028.tsv
#     → saved to subset_028.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_029.tsv
#     → saved to subset_029.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_030.tsv
#     → saved to subset_030.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_031.tsv
#     → saved to subset_031.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_032.tsv
#     → saved to subset_032.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_033.tsv
#     → saved to subset_033.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_034.tsv
#     → saved to subset_034.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_035.tsv
#     → saved to subset_035.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_036.tsv
#     → saved to subset_036.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_037.tsv
#     → saved to subset_037.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_038.tsv
#     → saved to subset_038.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_039.tsv
#     → saved to subset_039.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_040.tsv
#     → saved to subset_040.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_041.tsv
#     → saved to subset_041.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_042.tsv
#     → saved to subset_042.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_043.tsv
#     → saved to subset_043.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_044.tsv
#     → saved to subset_044.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_045.tsv
#     → saved to subset_045.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_046.tsv
#     → saved to subset_046.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_047.tsv
#     → saved to subset_047.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_048.tsv
#     → saved to subset_048.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_049.tsv
#     → saved to subset_049.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_050.tsv
#     → saved to subset_050.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_051.tsv
#     → saved to subset_051.reaction_features_its_wl_h3_edge.pkl
# [+] ITS–WL precompute for subset_052.tsv
#     → saved to subset_052.reaction_features_its_wl_h3_edge.pkl
# [✓] ITS–WL precompute finished.
# [+] ITS–WL precompute for subset_001.tsv
#     → saved to subset_001.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_002.tsv
#     → saved to subset_002.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_003.tsv
#     → saved to subset_003.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_004.tsv
#     → saved to subset_004.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_005.tsv
#     → saved to subset_005.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_006.tsv
#     → saved to subset_006.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_007.tsv
#     → saved to subset_007.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_008.tsv
#     → saved to subset_008.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_009.tsv
#     → saved to subset_009.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_010.tsv
#     → saved to subset_010.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_011.tsv
#     → saved to subset_011.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_012.tsv
#     → saved to subset_012.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_013.tsv
#     → saved to subset_013.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_014.tsv
#     → saved to subset_014.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_015.tsv
#     → saved to subset_015.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_016.tsv
#     → saved to subset_016.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_017.tsv
#     → saved to subset_017.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_018.tsv
#     → saved to subset_018.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_019.tsv
#     → saved to subset_019.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_020.tsv
#     → saved to subset_020.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_021.tsv
#     → saved to subset_021.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_022.tsv
#     → saved to subset_022.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_023.tsv
#     → saved to subset_023.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_024.tsv
#     → saved to subset_024.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_025.tsv
#     → saved to subset_025.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_026.tsv
#     → saved to subset_026.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_027.tsv
#     → saved to subset_027.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_028.tsv
#     → saved to subset_028.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_029.tsv
#     → saved to subset_029.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_030.tsv
#     → saved to subset_030.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_031.tsv
#     → saved to subset_031.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_032.tsv
#     → saved to subset_032.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_033.tsv
#     → saved to subset_033.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_034.tsv
#     → saved to subset_034.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_035.tsv
#     → saved to subset_035.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_036.tsv
#     → saved to subset_036.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_037.tsv
#     → saved to subset_037.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_038.tsv
#     → saved to subset_038.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_039.tsv
#     → saved to subset_039.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_040.tsv
#     → saved to subset_040.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_041.tsv
#     → saved to subset_041.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_042.tsv
#     → saved to subset_042.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_043.tsv
#     → saved to subset_043.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_044.tsv
#     → saved to subset_044.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_045.tsv
#     → saved to subset_045.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_046.tsv
#     → saved to subset_046.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_047.tsv
#     → saved to subset_047.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_048.tsv
#     → saved to subset_048.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_049.tsv
#     → saved to subset_049.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_050.tsv
#     → saved to subset_050.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_051.tsv
#     → saved to subset_051.reaction_features_its_wl_h3_vertex.pkl
# [+] ITS–WL precompute for subset_052.tsv
#     → saved to subset_052.reaction_features_its_wl_h3_vertex.pkl
# [✓] ITS–WL precompute finished.
# [+] ITS–WL precompute for subset_001.tsv
#     → saved to subset_001.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_002.tsv
#     → saved to subset_002.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_003.tsv
#     → saved to subset_003.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_004.tsv
#     → saved to subset_004.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_005.tsv
#     → saved to subset_005.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_006.tsv
#     → saved to subset_006.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_007.tsv
#     → saved to subset_007.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_008.tsv
#     → saved to subset_008.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_009.tsv
#     → saved to subset_009.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_010.tsv
#     → saved to subset_010.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_011.tsv
#     → saved to subset_011.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_012.tsv
#     → saved to subset_012.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_013.tsv
#     → saved to subset_013.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_014.tsv
#     → saved to subset_014.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_015.tsv
#     → saved to subset_015.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_016.tsv
#     → saved to subset_016.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_017.tsv
#     → saved to subset_017.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_018.tsv
#     → saved to subset_018.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_019.tsv
#     → saved to subset_019.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_020.tsv
#     → saved to subset_020.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_021.tsv
#     → saved to subset_021.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_022.tsv
#     → saved to subset_022.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_023.tsv
#     → saved to subset_023.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_024.tsv
#     → saved to subset_024.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_025.tsv
#     → saved to subset_025.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_026.tsv
#     → saved to subset_026.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_027.tsv
#     → saved to subset_027.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_028.tsv
#     → saved to subset_028.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_029.tsv
#     → saved to subset_029.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_030.tsv
#     → saved to subset_030.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_031.tsv
#     → saved to subset_031.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_032.tsv
#     → saved to subset_032.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_033.tsv
#     → saved to subset_033.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_034.tsv
#     → saved to subset_034.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_035.tsv
#     → saved to subset_035.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_036.tsv
#     → saved to subset_036.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_037.tsv
#     → saved to subset_037.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_038.tsv
#     → saved to subset_038.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_039.tsv
#     → saved to subset_039.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_040.tsv
#     → saved to subset_040.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_041.tsv
#     → saved to subset_041.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_042.tsv
#     → saved to subset_042.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_043.tsv
#     → saved to subset_043.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_044.tsv
#     → saved to subset_044.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_045.tsv
#     → saved to subset_045.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_046.tsv
#     → saved to subset_046.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_047.tsv
#     → saved to subset_047.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_048.tsv
#     → saved to subset_048.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_049.tsv
#     → saved to subset_049.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_050.tsv
#     → saved to subset_050.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_051.tsv
#     → saved to subset_051.reaction_features_its_wl_h3_sp.pkl
# [+] ITS–WL precompute for subset_052.tsv
#     → saved to subset_052.reaction_features_its_wl_h3_sp.pkl
# [✓] ITS–WL precompute finished.

# %%
for out_dir, mode in targets_big_its:
    out_dir.mkdir(parents=True, exist_ok=True)  
    print(f"write to {out_dir} (mode={mode})")
    precompute_all_subsets_in_dir_its_wl(
        subsets_dir=str(subsets_dir_big), 
        out_dir=str(out_dir),
        h=3,
        mode=mode,  # "edge" | "vertex" | "sp"
    )

# %% [markdown]
# ## Comparison of ITS–WL and DRF–WL Representations
#
# The following visualizations compare two WL-based reaction representations.
# The ITS–WL view applies Weisfeiler–Lehman relabeling to the Imaginary Transition State
# graph, illustrating how structural context is refined across iterations.
# In contrast, the DRF–WL visualization highlights graph elements that contribute to the
# reaction difference between reactants and products, thereby localizing the reaction
# center and its surrounding context.
#
# ITS–WL encodes structural context,
# DRF–WL localizes reaction-specific changes.

# %% [markdown]
# ### ITS–WL vs DRF–WL Feature Growth Across Iterations
#
# This plot compares how feature sets evolve across WL iterations for two reaction
# representations: ITS–WL (single reaction graph) and DRF–WL (difference between
# reactants and products). Aggregating over a subset provides a robust view of how
# quickly structural context is captured and whether feature growth saturates.

# %%
subset_df = pd.read_csv("subsets_small/subset_001.tsv", sep="\t")
# oder: subset_df = data.iloc[:60]

fig = plot_feature_growth_subset_its_vs_drf(subset_df, h=3, mode="edge", show_errorbars=True)
fig.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The plot shows the average growth of WL-based feature sets across iterations for two
# reaction representations: ITS–WL and DRF–WL.
# For ITS–WL, features are extracted from a single reaction graph, and their number
# increases steadily as larger structural neighborhoods are incorporated.
# In contrast, DRF–WL focuses on differences between reactants and products, resulting
# in a more compact feature set that grows more slowly and saturates earlier.
# This comparison illustrates that ITS–WL captures global structural context, whereas
# DRF–WL emphasizes reaction-specific changes and their local environment.
#
# ITS–WL wächst, weil es Struktur beschreibt.
# DRF–WL wächst langsamer, weil es nur Änderung beschreibt.
